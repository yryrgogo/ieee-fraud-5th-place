# %%
# %load_ext autoreload
# %autoreload 2
from glob import glob
import gc
import os
import sys
import datetime
import numpy as np
import pandas as pd
from tqdm import tqdm
from func.utils import get_numeric_features, get_categorical_features, read_pkl_gzip, to_pkl_gzip, parallel_load_data, get_filename
from func.time_utils import date_add_days
from func.ml_utils import save_feature, get_cnt_feature, get_dummie_feature, get_label_feature
from func.parallel_utils import get_parallel_arg_list
from joblib import delayed, Parallel

# %%
COLUMN_ID = 'TransactionID'
COLUMN_DT = 'TransactionDT'
COLUMN_TARGET = 'isFraud'
COLUMNS_IGNORE = [COLUMN_ID, COLUMN_DT, COLUMN_TARGET, 'ProductCD']

train_paths = glob('../feature/eda_base/*_train.gz')
test_paths = glob('../feature/eda_base/*_test.gz')
# train_paths += glob('../feature/org_use/526*_train.gz')
# test_paths  += glob('../feature/org_use/526*_test.gz')
train_paths += glob('../feature/raw_use/ker__uid*_train.gz')
test_paths  += glob('../feature/raw_use/ker__uid*_test.gz')

train_paths = [path for path in train_paths 
               if (path.count(COLUMN_DT) 
               or path.count(COLUMN_ID)
               or path.count(COLUMN_TARGET)
               or path.count('fill__M')
#                or path.count('V')
#                or path.count('C')
               or path.count('D1_')
#                or (path.count('526') and path.count('mean'))
#                or path.count('uid_')
               or path.count('uid2_t')
               or path.count('uid3_t')
               or path.count('uid4_t')
#                or path.count('uid5_t')
#                or path.count('card')
#                or path.count('addr')
               or path.count('domain')
               or path.startswith('TransactionAmt')
               or path.count('Product')
               or path.count('hour')
               or path.count('zone')
               )
#                and not path.count('fill')
               and not path.count('bin')
               and not path.count('129')
               and not path.count('130')
               or path.count('501')
              ]
test_paths = [path for path in test_paths 
               if (path.count(COLUMN_DT) 
               or path.count(COLUMN_ID)
               or path.count(COLUMN_TARGET)
               or path.count('fill__M')
#                or path.count('V')
#                or path.count('C')
               or path.count('D1_')
#                or (path.count('526') and path.count('mean'))
#                or path.count('uid_')
               or path.count('uid2_t')
               or path.count('uid3_t')
               or path.count('uid4_t')
#                or path.count('uid5_t')
#                or path.count('card')
#                or path.count('addr')
               or path.count('domain')
               or path.startswith('TransactionAmt')
               or path.count('Product')
               or path.count('hour')
               or path.count('zone')
               or path.count('501')
               )
#                and not path.count('fill')
               and not path.count('bin')
               and not path.count('129')
               and not path.count('130')
              ]

df_train = parallel_load_data(train_paths)
df_test = parallel_load_data(test_paths)
data = pd.concat([df_train, df_test], axis=0, ignore_index=True)
train_length = df_train.shape[0]

# %%
START_DATE = '2017-12-01'
# START_DATE = '2017-12-01'
startdate = datetime.datetime.strptime(START_DATE, '%Y-%m-%d')

data['datetime'] = data['TransactionDT'].apply(lambda x: (startdate + datetime.timedelta(seconds = x) - datetime.timedelta(seconds = 14400) ))
data['datetime'].fillna(datetime.date(2020, 1, 1), inplace=True)
data['date'] = data['datetime'].map(lambda x: x.date())

list_regist = []
for d, diff in tqdm(data[['date', 'D1']].values):
    if diff < 999999:
        regist = date_add_days(d, -1*diff)
    else:
        regist = date_add_days(d, 0)
    list_regist.append(str(regist))

data['Regist_date'] = list_regist
# Out:
# 100%|██████████| 1097231/1097231 [00:04<00:00, 243685.55it/s]

# %%
cols_uid = [col for col in data.columns if col.count('uid')]
cols_M = [col for col in data.columns if col.count('M')]
cols_domain = [col for col in data.columns if col.count('domain')]
cols_501 = [col for col in data.columns if col.count('501')]
cols_time = ['hour', 'time_zone']
cos_pd = ['ProductCD']

# %%
list_base_key = cols_uid
col_cat = 'ProductCD'
dir_save = 'valid_use'

for base_key in list_base_key:

    if str(type(base_key)).count('list'):
        pass
    else:
        base_key = [base_key]
    
    base_key += ['Regist_date']
    name_base = '-'.join(base_key)
    
    base = data[base_key]
    
    all_cnt = data.groupby(base_key, as_index=False)[col_cat].agg({
        f'count': 'count'
    })
    
    part_cnt = data.groupby(base_key + [col_cat], as_index=False)[col_cat].agg({
        f'count_cat': 'count'
    })
    
    tmp = all_cnt.merge(part_cnt[base_key + [f"count_cat", col_cat]], how='inner', on=base_key)
    
    tmp['cat_ratio'] = tmp['count_cat'] / tmp['count']
    tmp.drop(['count', 'count_cat'], axis=1, inplace=True)
    
    result = pd.pivot_table(data=tmp, columns=col_cat, index=base_key)
    cols_save = [f"cnt_ratio-{col_cat}-{col[1]}-{name_base}".replace('.', '_') for col in result.columns]
    result.columns = cols_save
    df_feat = base.merge(result, how='left', on=base_key)
    
    base_train = df_feat.iloc[:df_train.shape[0]]
    base_test  = df_feat.iloc[df_train.shape[0]:]
    
    save_feature(base_train[cols_save], '533', dir_save, is_train=True, auto_type=True, list_ignore=COLUMNS_IGNORE)
    save_feature(base_test[cols_save],  '533', dir_save, is_train=False, auto_type=True, list_ignore=COLUMNS_IGNORE)
# Out:
# (590540,) | cnt_ratio-ProductCD-C-ker__uid2-Regist_date
# (590540,) | cnt_ratio-ProductCD-H-ker__uid2-Regist_date
# (590540,) | cnt_ratio-ProductCD-R-ker__uid2-Regist_date
# (590540,) | cnt_ratio-ProductCD-S-ker__uid2-Regist_date
# (590540,) | cnt_ratio-ProductCD-W-ker__uid2-Regist_date
# (506691,) | cnt_ratio-ProductCD-C-ker__uid2-Regist_date
# (506691,) | cnt_ratio-ProductCD-H-ker__uid2-Regist_date
# (506691,) | cnt_ratio-ProductCD-R-ker__uid2-Regist_date
# (506691,) | cnt_ratio-ProductCD-S-ker__uid2-Regist_date
# (506691,) | cnt_ratio-ProductCD-W-ker__uid2-Regist_date
# (590540,) | cnt_ratio-ProductCD-C-ker__uid3-Regist_date
# (590540,) | cnt_ratio-ProductCD-H-ker__uid3-Regist_date
# (590540,) | cnt_ratio-ProductCD-R-ker__uid3-Regist_date
# (590540,) | cnt_ratio-ProductCD-S-ker__uid3-Regist_date
# (590540,) | cnt_ratio-ProductCD-W-ker__uid3-Regist_date
# (506691,) | cnt_ratio-ProductCD-C-ker__uid3-Regist_date
# (506691,) | cnt_ratio-ProductCD-H-ker__uid3-Regist_date
# (506691,) | cnt_ratio-ProductCD-R-ker__uid3-Regist_date
# (506691,) | cnt_ratio-ProductCD-S-ker__uid3-Regist_date
# (506691,) | cnt_ratio-ProductCD-W-ker__uid3-Regist_date
# (590540,) | cnt_ratio-ProductCD-C-ker__uid4-Regist_date
# (590540,) | cnt_ratio-ProductCD-H-ker__uid4-Regist_date
# (590540,) | cnt_ratio-ProductCD-R-ker__uid4-Regist_date
# (590540,) | cnt_ratio-ProductCD-S-ker__uid4-Regist_date
# (590540,) | cnt_ratio-ProductCD-W-ker__uid4-Regist_date
# (506691,) | cnt_ratio-ProductCD-C-ker__uid4-Regist_date
# (506691,) | cnt_ratio-ProductCD-H-ker__uid4-Regist_date
# (506691,) | cnt_ratio-ProductCD-R-ker__uid4-Regist_date
# (506691,) | cnt_ratio-ProductCD-S-ker__uid4-Regist_date
# (506691,) | cnt_ratio-ProductCD-W-ker__uid4-Regist_date

# %%
list_base_key = cols_uid
cat_list = cols_M
dir_save = 'valid_use'

for base_key in list_base_key:
    
    if str(type(base_key)).count('list'):
        pass
    else:
        base_key = [base_key]
        
    base_key += ['Regist_date']
    name_base = '-'.join(base_key)

    base = data[base_key]
    
    for col_cat in cat_list:


        all_cnt = data.groupby(base_key, as_index=False)[col_cat].agg({
            f'count': 'count'
        })

        part_cnt = data.groupby(base_key + [col_cat], as_index=False)[col_cat].agg({
            f'count_cat': 'count'
        })

        tmp = all_cnt.merge(part_cnt[base_key + [f"count_cat", col_cat]], how='inner', on=base_key)

        tmp['cat_ratio'] = tmp['count_cat'] / tmp['count']
        tmp.drop(['count', 'count_cat'], axis=1, inplace=True)

        result = pd.pivot_table(data=tmp, columns=col_cat, index=base_key)
        cols_save = [f"cnt_ratio-{col_cat}-{col[1]}-{name_base}".replace('.', '_') for col in result.columns]
        result.columns = cols_save
        df_feat = base.merge(result, how='left', on=base_key)

        base_train = df_feat.iloc[:df_train.shape[0]]
        base_test  = df_feat.iloc[df_train.shape[0]:]

        save_feature(base_train[cols_save], '533', dir_save, is_train=True, auto_type=True, list_ignore=COLUMNS_IGNORE)
        save_feature(base_test[cols_save],  '533', dir_save, is_train=False, auto_type=True, list_ignore=COLUMNS_IGNORE)
# Out:
# (590540,) | cnt_ratio-fill__M1-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M1-F-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M1-T-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M1-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M1-F-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M1-T-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M2-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M2-F-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M2-T-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M2-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M2-F-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M2-T-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M3-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M3-F-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M3-T-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M3-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M3-F-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M3-T-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M4-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M4-M0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M4-M1-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M4-M2-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M4-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M4-M0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M4-M1-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M4-M2-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M5-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M5-F-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M5-T-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M5-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M5-F-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M5-T-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M6-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M6-F-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M6-T-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M6-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M6-F-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M6-T-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M7-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M7-F-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M7-T-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M7-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M7-F-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M7-T-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M8-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M8-F-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M8-T-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M8-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M8-F-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M8-T-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M9-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M9-F-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M9-T-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M9-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M9-F-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M9-T-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M1-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M1-F-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M1-T-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M1-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M1-F-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M1-T-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M2-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M2-F-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M2-T-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M2-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M2-F-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M2-T-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M3-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M3-F-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M3-T-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M3-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M3-F-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M3-T-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M4-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M4-M0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M4-M1-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M4-M2-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M4-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M4-M0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M4-M1-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M4-M2-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M5-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M5-F-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M5-T-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M5-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M5-F-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M5-T-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M6-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M6-F-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M6-T-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M6-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M6-F-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M6-T-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M7-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M7-F-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M7-T-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M7-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M7-F-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M7-T-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M8-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M8-F-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M8-T-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M8-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M8-F-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M8-T-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M9-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M9-F-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M9-T-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M9-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M9-F-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M9-T-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M1-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M1-F-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M1-T-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M1-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M1-F-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M1-T-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M2-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M2-F-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M2-T-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M2-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M2-F-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M2-T-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M3-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M3-F-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M3-T-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M3-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M3-F-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M3-T-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M4-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M4-M0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M4-M1-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M4-M2-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M4-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M4-M0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M4-M1-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M4-M2-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M5-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M5-F-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M5-T-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M5-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M5-F-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M5-T-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M6-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M6-F-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M6-T-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M6-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M6-F-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M6-T-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M7-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M7-F-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M7-T-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M7-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M7-F-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M7-T-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M8-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M8-F-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M8-T-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M8-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M8-F-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M8-T-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M9-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M9-F-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M9-T-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M9-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M9-F-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M9-T-ker__uid4-Regist_date

# %%
list_base_key = cols_uid
cat_list = cols_domain
dir_save = 'valid_use'

for base_key in list_base_key:
    
    if str(type(base_key)).count('list'):
        pass
    else:
        base_key = [base_key]
        
    base_key += ['Regist_date']
    name_base = '-'.join(base_key)

    base = data[base_key]
    
    for col_cat in cat_list:


        all_cnt = data.groupby(base_key, as_index=False)[col_cat].agg({
            f'count': 'count'
        })

        part_cnt = data.groupby(base_key + [col_cat], as_index=False)[col_cat].agg({
            f'count_cat': 'count'
        })

        tmp = all_cnt.merge(part_cnt[base_key + [f"count_cat", col_cat]], how='inner', on=base_key)

        tmp['cat_ratio'] = tmp['count_cat'] / tmp['count']
        tmp.drop(['count', 'count_cat'], axis=1, inplace=True)

        result = pd.pivot_table(data=tmp, columns=col_cat, index=base_key)
        cols_save = [f"cnt_ratio-{col_cat}-{col[1]}-{name_base}".replace('.', '_') for col in result.columns]
        result.columns = cols_save
        df_feat = base.merge(result, how='left', on=base_key)

        base_train = df_feat.iloc[:df_train.shape[0]]
        base_test  = df_feat.iloc[df_train.shape[0]:]

        save_feature(base_train[cols_save], '533', dir_save, is_train=True, auto_type=True, list_ignore=COLUMNS_IGNORE)
        save_feature(base_test[cols_save],  '533', dir_save, is_train=False, auto_type=True, list_ignore=COLUMNS_IGNORE)
# Out:
# (590540,) | cnt_ratio-P_emaildomain-aim_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-anonymous_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-aol_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-att_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-bellsouth_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-cableone_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-centurylink_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-cfl_rr_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-charter_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-comcast_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-cox_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-earthlink_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-embarqmail_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-frontier_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-frontiernet_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-gmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-gmail_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-gmx_de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-hotmail_co_uk-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-hotmail_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-hotmail_de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-hotmail_es-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-hotmail_fr-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-icloud_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-juno_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-live_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-live_com_mx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-live_fr-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-mac_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-mail_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-me_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-msn_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-netzero_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-netzero_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-optonline_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-outlook_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-outlook_es-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-prodigy_net_mx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-protonmail_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-ptd_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-q_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-roadrunner_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-rocketmail_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-sbcglobal_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-sc_rr_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-scranton_edu-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-servicios-ta_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-suddenlink_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-twc_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-verizon_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-web_de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-windstream_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-yahoo_co_jp-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-yahoo_co_uk-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-yahoo_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-yahoo_com_mx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-yahoo_de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-yahoo_es-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-yahoo_fr-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-ymail_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-aim_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-anonymous_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-aol_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-att_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-bellsouth_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-cableone_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-centurylink_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-cfl_rr_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-charter_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-comcast_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-cox_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-earthlink_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-embarqmail_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-frontier_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-frontiernet_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-gmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-gmail_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-gmx_de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-hotmail_co_uk-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-hotmail_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-hotmail_de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-hotmail_es-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-hotmail_fr-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-icloud_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-juno_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-live_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-live_com_mx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-live_fr-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-mac_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-mail_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-me_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-msn_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-netzero_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-netzero_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-optonline_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-outlook_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-outlook_es-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-prodigy_net_mx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-protonmail_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-ptd_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-q_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-roadrunner_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-rocketmail_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-sbcglobal_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-sc_rr_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-scranton_edu-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-servicios-ta_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-suddenlink_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-twc_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-verizon_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-web_de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-windstream_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-yahoo_co_jp-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-yahoo_co_uk-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-yahoo_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-yahoo_com_mx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-yahoo_de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-yahoo_es-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-yahoo_fr-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-ymail_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-aim_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-anonymous_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-aol_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-att_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-bellsouth_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-cableone_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-centurylink_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-cfl_rr_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-charter_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-comcast_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-cox_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-earthlink_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-embarqmail_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-frontier_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-frontiernet_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-gmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-gmail_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-gmx_de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-hotmail_co_uk-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-hotmail_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-hotmail_de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-hotmail_es-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-hotmail_fr-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-icloud_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-juno_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-live_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-live_com_mx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-live_fr-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-mac_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-mail_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-me_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-msn_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-netzero_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-netzero_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-optonline_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-outlook_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-outlook_es-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-prodigy_net_mx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-protonmail_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-ptd_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-q_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-roadrunner_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-rocketmail_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-sbcglobal_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-sc_rr_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-scranton_edu-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-servicios-ta_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-suddenlink_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-twc_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-verizon_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-web_de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-windstream_net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-yahoo_co_jp-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-yahoo_co_uk-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-yahoo_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-yahoo_com_mx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-yahoo_de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-yahoo_es-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-yahoo_fr-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-ymail_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-aim_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-anonymous_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-aol_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-att_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-bellsouth_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-cableone_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-centurylink_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-cfl_rr_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-charter_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-comcast_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-cox_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-earthlink_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-embarqmail_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-frontier_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-frontiernet_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-gmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-gmail_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-gmx_de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-hotmail_co_uk-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-hotmail_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-hotmail_de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-hotmail_es-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-hotmail_fr-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-icloud_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-juno_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-live_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-live_com_mx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-live_fr-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-mac_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-mail_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-me_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-msn_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-netzero_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-netzero_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-optonline_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-outlook_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-outlook_es-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-prodigy_net_mx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-protonmail_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-ptd_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-q_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-roadrunner_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-rocketmail_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-sbcglobal_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-sc_rr_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-scranton_edu-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-servicios-ta_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-suddenlink_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-twc_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-verizon_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-web_de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-windstream_net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-yahoo_co_jp-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-yahoo_co_uk-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-yahoo_com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-yahoo_com_mx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-yahoo_de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-yahoo_es-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-yahoo_fr-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-ymail_com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-aim-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-anonymous-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-aol-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-att-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-bellsouth-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-cableone-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-centurylink-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-cfl-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-charter-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-comcast-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-cox-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-earthlink-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-embarqmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-frontier-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-frontiernet-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-gmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-gmx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-hotmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-icloud-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-juno-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-live-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-mac-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-mail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-me-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-msn-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-netzero-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-optonline-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-outlook-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-prodigy-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-protonmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-ptd-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-q-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-roadrunner-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-rocketmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-sbcglobal-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-sc-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-scranton-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-servicios-ta-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-suddenlink-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-twc-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-verizon-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-web-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-windstream-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-yahoo-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-ymail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-aim-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-anonymous-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-aol-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-att-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-bellsouth-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-cableone-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-centurylink-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-cfl-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-charter-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-comcast-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-cox-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-earthlink-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-embarqmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-frontier-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-frontiernet-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-gmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-gmx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-hotmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-icloud-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-juno-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-live-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-mac-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-mail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-me-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-msn-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-netzero-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-optonline-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-outlook-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-prodigy-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-protonmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-ptd-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-q-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-roadrunner-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-rocketmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-sbcglobal-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-sc-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-scranton-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-servicios-ta-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-suddenlink-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-twc-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-verizon-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-web-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-windstream-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-yahoo-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-ymail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-es-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-fr-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-jp-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-mx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-uk-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-us-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-es-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-fr-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-jp-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-mx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-uk-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-us-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-aim-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-anonymous-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-aol-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-att-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-bellsouth-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-cableone-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-centurylink-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-cfl-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-charter-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-comcast-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-cox-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-earthlink-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-embarqmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-frontier-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-frontiernet-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-gmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-gmx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-hotmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-icloud-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-juno-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-live-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-mac-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-mail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-me-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-msn-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-netzero-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-optonline-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-outlook-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-prodigy-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-protonmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-ptd-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-q-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-roadrunner-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-rocketmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-sbcglobal-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-sc-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-scranton-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-servicios-ta-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-suddenlink-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-twc-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-verizon-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-web-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-windstream-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-yahoo-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-ymail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-aim-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-anonymous-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-aol-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-att-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-bellsouth-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-cableone-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-centurylink-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-cfl-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-charter-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-comcast-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-cox-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-earthlink-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-embarqmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-frontier-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-frontiernet-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-gmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-gmx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-hotmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-icloud-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-juno-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-live-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-mac-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-mail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-me-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-msn-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-netzero-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-optonline-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-outlook-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-prodigy-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-protonmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-ptd-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-q-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-roadrunner-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-rocketmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-sbcglobal-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-sc-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-scranton-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-servicios-ta-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-suddenlink-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-twc-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-verizon-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-web-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-windstream-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-yahoo-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-ymail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-es-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-fr-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-jp-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-mx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-uk-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-us-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-es-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-fr-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-jp-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-mx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-uk-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-us-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-2-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-80-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-101-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-103-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-106-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-130-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-137-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-140-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-159-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-272-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-277-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-298-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-303-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-311-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-318-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-319-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-323-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-334-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-344-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-362-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-386-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-387-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-397-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-439-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-464-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-468-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-518-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-552-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-574-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-583-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-594-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-627-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-674-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-862-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-863-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-979-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-993-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1105-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1156-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1443-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1470-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1937-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-2657-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-2713-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-2827-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-3437-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-4075-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-5011-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-5720-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-5767-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-7480-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-7647-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-9934-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-12316-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-14474-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-52337-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-71062-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-85649-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-163648-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-182784-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-435803-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-2-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-80-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-101-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-103-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-106-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-130-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-137-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-140-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-159-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-272-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-277-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-298-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-303-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-311-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-318-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-319-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-323-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-334-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-344-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-362-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-386-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-387-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-397-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-439-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-464-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-468-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-518-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-552-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-574-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-583-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-594-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-627-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-674-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-862-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-863-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-979-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-993-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1105-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1156-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1443-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1470-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1937-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-2657-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-2713-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-2827-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-3437-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-4075-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-5011-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-5720-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-5767-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-7480-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-7647-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-9934-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-12316-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-14474-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-52337-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-71062-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-85649-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-163648-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-182784-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-435803-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-14-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-19-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-24-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-28-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-38-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-45-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-46-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-55-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-57-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-61-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-69-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-70-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-75-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-77-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-80-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-82-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-101-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-104-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-105-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-110-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-111-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-124-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-126-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-130-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-139-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-140-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-170-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-196-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-263-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-297-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-303-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-315-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-317-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-341-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-350-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-405-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-430-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-514-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-595-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-667-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-795-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-853-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-854-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-870-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1095-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1163-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1202-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1444-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1464-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1698-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-2743-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-2820-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-3513-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-5011-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-7239-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-21405-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-39644-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-53166-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-118885-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-824070-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-14-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-19-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-24-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-28-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-38-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-45-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-46-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-55-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-57-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-61-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-69-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-70-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-75-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-77-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-80-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-82-ker__uid2-Regist_date
# ...
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-frontiernet-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-gmail-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-gmx-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-hotmail-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-icloud-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-juno-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-live-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-mac-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-mail-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-me-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-msn-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-netzero-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-optonline-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-outlook-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-prodigy-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-protonmail-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-ptd-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-q-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-roadrunner-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-rocketmail-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-sbcglobal-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-sc-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-scranton-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-servicios-ta-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-suddenlink-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-twc-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-verizon-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-web-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-windstream-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-yahoo-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-ymail-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-aim-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-anonymous-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-aol-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-att-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-bellsouth-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-cableone-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-centurylink-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-cfl-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-charter-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-comcast-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-cox-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-earthlink-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-embarqmail-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-frontier-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-frontiernet-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-gmail-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-gmx-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-hotmail-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-icloud-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-juno-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-live-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-mac-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-mail-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-me-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-msn-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-netzero-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-optonline-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-outlook-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-prodigy-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-protonmail-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-ptd-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-q-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-roadrunner-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-rocketmail-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-sbcglobal-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-sc-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-scranton-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-servicios-ta-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-suddenlink-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-twc-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-verizon-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-web-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-windstream-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-yahoo-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-ymail-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-com-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-de-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-es-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-fr-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-jp-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-mx-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-uk-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-us-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-com-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-de-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-es-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-fr-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-jp-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-mx-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-uk-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-us-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-2-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-80-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-101-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-103-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-106-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-130-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-137-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-140-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-159-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-272-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-277-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-298-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-303-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-311-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-318-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-319-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-323-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-334-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-344-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-362-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-386-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-387-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-397-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-439-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-464-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-468-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-518-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-552-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-574-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-583-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-594-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-627-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-674-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-862-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-863-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-979-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-993-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1105-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1156-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1443-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1470-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1937-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-2657-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-2713-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-2827-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-3437-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-4075-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-5011-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-5720-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-5767-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-7480-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-7647-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-9934-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-12316-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-14474-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-52337-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-71062-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-85649-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-163648-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-182784-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-435803-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-2-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-80-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-101-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-103-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-106-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-130-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-137-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-140-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-159-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-272-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-277-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-298-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-303-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-311-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-318-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-319-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-323-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-334-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-344-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-362-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-386-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-387-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-397-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-439-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-464-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-468-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-518-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-552-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-574-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-583-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-594-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-627-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-674-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-862-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-863-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-979-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-993-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1105-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1156-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1443-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1470-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1937-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-2657-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-2713-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-2827-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-3437-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-4075-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-5011-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-5720-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-5767-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-7480-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-7647-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-9934-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-12316-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-14474-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-52337-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-71062-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-85649-ker__uid3-Regist_date

# %%
list_base_key = cols_uid
cat_list = cols_time
dir_save = 'valid_use'

for base_key in list_base_key:
    
    if str(type(base_key)).count('list'):
        pass
    else:
        base_key = [base_key]
        
    base_key += ['Regist_date']
    name_base = '-'.join(base_key)

    base = data[base_key]
    
    for col_cat in cat_list:


        all_cnt = data.groupby(base_key, as_index=False)[col_cat].agg({
            f'count': 'count'
        })

        part_cnt = data.groupby(base_key + [col_cat], as_index=False)[col_cat].agg({
            f'count_cat': 'count'
        })

        tmp = all_cnt.merge(part_cnt[base_key + [f"count_cat", col_cat]], how='inner', on=base_key)

        tmp['cat_ratio'] = tmp['count_cat'] / tmp['count']
        tmp.drop(['count', 'count_cat'], axis=1, inplace=True)

        result = pd.pivot_table(data=tmp, columns=col_cat, index=base_key)
        cols_save = [f"cnt_ratio-{col_cat}-{col[1]}-{name_base}".replace('.', '_') for col in result.columns]
        result.columns = cols_save
        df_feat = base.merge(result, how='left', on=base_key)

        base_train = df_feat.iloc[:df_train.shape[0]]
        base_test  = df_feat.iloc[df_train.shape[0]:]

        save_feature(base_train[cols_save], '533', dir_save, is_train=True, auto_type=True, list_ignore=COLUMNS_IGNORE)
        save_feature(base_test[cols_save],  '533', dir_save, is_train=False, auto_type=True, list_ignore=COLUMNS_IGNORE)

# %%
list_base_key = cols_uid
cat_list = cols_501
dir_save = 'valid_use'

for base_key in list_base_key:
    
    if str(type(base_key)).count('list'):
        pass
    else:
        base_key = [base_key]
        
    base_key += ['Regist_date']
    name_base = '-'.join(base_key)

    base = data[base_key]
    
    for col_cat in cat_list:


        all_cnt = data.groupby(base_key, as_index=False)[col_cat].agg({
            f'count': 'count'
        })

        part_cnt = data.groupby(base_key + [col_cat], as_index=False)[col_cat].agg({
            f'count_cat': 'count'
        })

        tmp = all_cnt.merge(part_cnt[base_key + [f"count_cat", col_cat]], how='inner', on=base_key)

        tmp['cat_ratio'] = tmp['count_cat'] / tmp['count']
        tmp.drop(['count', 'count_cat'], axis=1, inplace=True)

        result = pd.pivot_table(data=tmp, columns=col_cat, index=base_key)
        cols_save = [f"cnt_ratio-{col_cat}-{col[1]}-{name_base}".replace('.', '_') for col in result.columns]
        result.columns = cols_save
        df_feat = base.merge(result, how='left', on=base_key)

        base_train = df_feat.iloc[:df_train.shape[0]]
        base_test  = df_feat.iloc[df_train.shape[0]:]

        save_feature(base_train[cols_save], '533', dir_save, is_train=True, auto_type=True, list_ignore=COLUMNS_IGNORE)
        save_feature(base_test[cols_save],  '533', dir_save, is_train=False, auto_type=True, list_ignore=COLUMNS_IGNORE)
