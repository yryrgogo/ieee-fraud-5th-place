# %%
# %load_ext autoreload
# %autoreload 2
from glob import glob
import gc
import os
import sys
import datetime
import numpy as np
import pandas as pd
from tqdm import tqdm
from func.utils import get_numeric_features, get_categorical_features, read_pkl_gzip, to_pkl_gzip, parallel_load_data, get_filename
from func.time_utils import date_add_days
from func.ml_utils import save_feature, get_cnt_feature, get_dummie_feature, get_label_feature
from func.parallel_utils import get_parallel_arg_list
from joblib import delayed, Parallel

# %%
COLUMN_ID = 'TransactionID'
COLUMN_DT = 'TransactionDT'
COLUMN_TARGET = 'isFraud'
COLUMNS_IGNORE = [COLUMN_ID, COLUMN_DT, COLUMN_TARGET, 'ProductCD']

train_paths = glob('../feature/eda_base/*_train.gz')
test_paths = glob('../feature/eda_base/*_test.gz')
train_paths += glob('../feature/org_use/526*_train.gz')
test_paths  += glob('../feature/org_use/526*_test.gz')
train_paths += glob('../feature/raw_use/ker__uid*_train.gz')
test_paths  += glob('../feature/raw_use/ker__uid*_test.gz')

train_paths = [path for path in train_paths 
               if (path.count(COLUMN_DT) 
               or path.count(COLUMN_ID)
               or path.count(COLUMN_TARGET)
               or path.count('fill__M')
#                or path.count('V')
#                or path.count('C')
               or path.count('D1_')
#                or (path.count('526') and path.count('mean'))
#                or path.count('uid_')
               or path.count('uid2_t')
               or path.count('uid3_t')
               or path.count('uid4_t')
#                or path.count('uid5_t')
#                or path.count('card')
#                or path.count('addr')
               or path.count('domain')
               or path.startswith('TransactionAmt')
               or path.count('Product')
               or path.count('hour')
               or path.count('zone')
               )
#                and not path.count('fill')
               and not path.count('bin')
               and not path.count('129')
               and not path.count('130')
               or path.count('501')
              ]
test_paths = [path for path in test_paths 
               if (path.count(COLUMN_DT) 
               or path.count(COLUMN_ID)
               or path.count(COLUMN_TARGET)
               or path.count('fill__M')
#                or path.count('V')
#                or path.count('C')
               or path.count('D1_')
#                or (path.count('526') and path.count('mean'))
#                or path.count('uid_')
               or path.count('uid2_t')
               or path.count('uid3_t')
               or path.count('uid4_t')
#                or path.count('uid5_t')
#                or path.count('card')
#                or path.count('addr')
               or path.count('domain')
               or path.startswith('TransactionAmt')
               or path.count('Product')
               or path.count('hour')
               or path.count('zone')
               or path.count('501')
               )
#                and not path.count('fill')
               and not path.count('bin')
               and not path.count('129')
               and not path.count('130')
              ]

df_train = parallel_load_data(train_paths)
df_test = parallel_load_data(test_paths)
data = pd.concat([df_train, df_test], axis=0, ignore_index=True)
train_length = df_train.shape[0]

# %%
START_DATE = '2017-12-01'
# START_DATE = '2017-12-01'
startdate = datetime.datetime.strptime(START_DATE, '%Y-%m-%d')

data['datetime'] = data['TransactionDT'].apply(lambda x: (startdate + datetime.timedelta(seconds = x) - datetime.timedelta(seconds = 14400) ))
data['datetime'].fillna(datetime.date(2020, 1, 1), inplace=True)
data['date'] = data['datetime'].map(lambda x: x.date())

list_regist = []
for d, diff in tqdm(data[['date', 'D1']].values):
    if diff < 999999:
        regist = date_add_days(d, -1*diff)
    else:
        regist = date_add_days(d, 0)
    list_regist.append(str(regist))

data['Regist_date'] = list_regist
# Out:
# 100%|██████████| 1097231/1097231 [00:04<00:00, 258036.12it/s]

# %%
cols_uid = [col for col in data.columns if col.count('uid')]
cols_M = [col for col in data.columns if col.count('M')]
cols_domain = [col for col in data.columns if col.count('domain')]
cols_501 = [col for col in data.columns if col.count('501')]
cols_time = ['hour', 'time_zone']
cos_pd = ['ProductCD']

# %%
list_base_key = cols_uid
col_cat = 'ProductCD'
dir_save = 'valid_use'

for base_key in list_base_key:

    if str(type(base_key)).count('list'):
        pass
    else:
        base_key = [base_key]
    
    base_key += ['Regist_date']
    name_base = '-'.join(base_key)
    
    base = data[base_key]
    
    all_cnt = data.groupby(base_key, as_index=False)[col_cat].agg({
        f'count': 'count'
    })
    
    part_cnt = data.groupby(base_key + [col_cat], as_index=False)[col_cat].agg({
        f'count_cat': 'count'
    })
    
    tmp = all_cnt.merge(part_cnt[base_key + [f"count_cat", col_cat]], how='inner', on=base_key)
    
    tmp['cat_ratio'] = tmp['count_cat'] / tmp['count']
    tmp.drop(['count', 'count_cat'], axis=1, inplace=True)
    
    result = pd.pivot_table(data=tmp, columns=col_cat, index=base_key)
    cols_save = [f"cnt_ratio-{col_cat}-{col[1]}-{name_base}" for col in result.columns]
    result.columns = cols_save
    df_feat = base.merge(result, how='left', on=base_key)
    
    base_train = df_feat.iloc[:df_train.shape[0]]
    base_test  = df_feat.iloc[df_train.shape[0]:]
    
    save_feature(base_train[cols_save], '533', dir_save, is_train=True, auto_type=True, list_ignore=COLUMNS_IGNORE)
    save_feature(base_test[cols_save],  '533', dir_save, is_train=False, auto_type=True, list_ignore=COLUMNS_IGNORE)

# %%
list_base_key = cols_uid
cat_list = cols_M
dir_save = 'valid_use'

for base_key in list_base_key:
    
    if str(type(base_key)).count('list'):
        pass
    else:
        base_key = [base_key]
        
    base_key += ['Regist_date']
    name_base = '-'.join(base_key)

    base = data[base_key]
    
    for col_cat in cat_list:


        all_cnt = data.groupby(base_key, as_index=False)[col_cat].agg({
            f'count': 'count'
        })

        part_cnt = data.groupby(base_key + [col_cat], as_index=False)[col_cat].agg({
            f'count_cat': 'count'
        })

        tmp = all_cnt.merge(part_cnt[base_key + [f"count_cat", col_cat]], how='inner', on=base_key)

        tmp['cat_ratio'] = tmp['count_cat'] / tmp['count']
        tmp.drop(['count', 'count_cat'], axis=1, inplace=True)

        result = pd.pivot_table(data=tmp, columns=col_cat, index=base_key)
        cols_save = [f"cnt_ratio-{col_cat}-{col[1]}-{name_base}" for col in result.columns]
        result.columns = cols_save
        df_feat = base.merge(result, how='left', on=base_key)

        base_train = df_feat.iloc[:df_train.shape[0]]
        base_test  = df_feat.iloc[df_train.shape[0]:]

        save_feature(base_train[cols_save], '533', dir_save, is_train=True, auto_type=True, list_ignore=COLUMNS_IGNORE)
        save_feature(base_test[cols_save],  '533', dir_save, is_train=False, auto_type=True, list_ignore=COLUMNS_IGNORE)
# Out:
# (590540,) | cnt_ratio-fill__M1-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M1-F-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M1-T-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M1-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M1-F-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M1-T-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M2-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M2-F-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M2-T-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M2-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M2-F-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M2-T-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M3-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M3-F-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M3-T-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M3-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M3-F-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M3-T-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M4-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M4-M0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M4-M1-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M4-M2-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M4-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M4-M0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M4-M1-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M4-M2-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M5-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M5-F-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M5-T-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M5-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M5-F-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M5-T-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M6-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M6-F-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M6-T-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M6-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M6-F-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M6-T-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M7-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M7-F-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M7-T-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M7-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M7-F-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M7-T-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M8-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M8-F-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M8-T-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M8-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M8-F-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M8-T-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M9-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M9-F-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M9-T-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M9-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M9-F-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__M9-T-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__M1-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M1-F-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M1-T-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M1-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M1-F-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M1-T-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M2-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M2-F-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M2-T-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M2-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M2-F-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M2-T-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M3-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M3-F-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M3-T-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M3-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M3-F-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M3-T-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M4-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M4-M0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M4-M1-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M4-M2-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M4-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M4-M0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M4-M1-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M4-M2-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M5-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M5-F-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M5-T-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M5-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M5-F-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M5-T-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M6-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M6-F-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M6-T-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M6-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M6-F-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M6-T-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M7-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M7-F-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M7-T-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M7-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M7-F-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M7-T-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M8-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M8-F-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M8-T-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M8-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M8-F-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M8-T-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M9-#-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M9-F-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M9-T-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M9-#-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M9-F-ker__uid3-Regist_date
# (506691,) | cnt_ratio-fill__M9-T-ker__uid3-Regist_date
# (590540,) | cnt_ratio-fill__M1-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M1-F-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M1-T-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M1-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M1-F-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M1-T-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M2-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M2-F-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M2-T-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M2-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M2-F-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M2-T-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M3-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M3-F-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M3-T-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M3-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M3-F-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M3-T-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M4-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M4-M0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M4-M1-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M4-M2-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M4-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M4-M0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M4-M1-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M4-M2-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M5-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M5-F-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M5-T-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M5-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M5-F-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M5-T-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M6-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M6-F-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M6-T-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M6-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M6-F-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M6-T-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M7-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M7-F-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M7-T-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M7-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M7-F-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M7-T-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M8-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M8-F-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M8-T-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M8-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M8-F-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M8-T-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M9-#-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M9-F-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__M9-T-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M9-#-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M9-F-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__M9-T-ker__uid4-Regist_date

# %%
list_base_key = cols_uid
cat_list = cols_domain
dir_save = 'valid_use'

for base_key in list_base_key:
    
    if str(type(base_key)).count('list'):
        pass
    else:
        base_key = [base_key]
        
    base_key += ['Regist_date']
    name_base = '-'.join(base_key)

    base = data[base_key]
    
    for col_cat in cat_list:


        all_cnt = data.groupby(base_key, as_index=False)[col_cat].agg({
            f'count': 'count'
        })

        part_cnt = data.groupby(base_key + [col_cat], as_index=False)[col_cat].agg({
            f'count_cat': 'count'
        })

        tmp = all_cnt.merge(part_cnt[base_key + [f"count_cat", col_cat]], how='inner', on=base_key)

        tmp['cat_ratio'] = tmp['count_cat'] / tmp['count']
        tmp.drop(['count', 'count_cat'], axis=1, inplace=True)

        result = pd.pivot_table(data=tmp, columns=col_cat, index=base_key)
        cols_save = [f"cnt_ratio-{col_cat}-{col[1]}-{name_base}" for col in result.columns]
        result.columns = cols_save
        df_feat = base.merge(result, how='left', on=base_key)

        base_train = df_feat.iloc[:df_train.shape[0]]
        base_test  = df_feat.iloc[df_train.shape[0]:]

        save_feature(base_train[cols_save], '533', dir_save, is_train=True, auto_type=True, list_ignore=COLUMNS_IGNORE)
        save_feature(base_test[cols_save],  '533', dir_save, is_train=False, auto_type=True, list_ignore=COLUMNS_IGNORE)
# Out:
# (590540,) | cnt_ratio-P_emaildomain-aim.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-anonymous.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-aol.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-att.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-bellsouth.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-cableone.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-centurylink.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-cfl.rr.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-charter.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-comcast.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-cox.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-earthlink.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-embarqmail.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-frontier.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-frontiernet.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-gmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-gmail.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-gmx.de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-hotmail.co.uk-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-hotmail.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-hotmail.de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-hotmail.es-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-hotmail.fr-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-icloud.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-juno.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-live.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-live.com.mx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-live.fr-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-mac.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-mail.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-me.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-msn.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-netzero.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-netzero.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-optonline.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-outlook.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-outlook.es-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-prodigy.net.mx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-protonmail.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-ptd.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-q.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-roadrunner.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-rocketmail.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-sbcglobal.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-sc.rr.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-scranton.edu-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-servicios-ta.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-suddenlink.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-twc.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-verizon.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-web.de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-windstream.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-yahoo.co.jp-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-yahoo.co.uk-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-yahoo.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-yahoo.com.mx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-yahoo.de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-yahoo.es-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-yahoo.fr-ker__uid2-Regist_date
# (590540,) | cnt_ratio-P_emaildomain-ymail.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-aim.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-anonymous.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-aol.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-att.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-bellsouth.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-cableone.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-centurylink.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-cfl.rr.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-charter.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-comcast.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-cox.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-earthlink.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-embarqmail.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-frontier.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-frontiernet.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-gmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-gmail.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-gmx.de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-hotmail.co.uk-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-hotmail.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-hotmail.de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-hotmail.es-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-hotmail.fr-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-icloud.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-juno.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-live.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-live.com.mx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-live.fr-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-mac.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-mail.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-me.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-msn.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-netzero.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-netzero.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-optonline.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-outlook.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-outlook.es-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-prodigy.net.mx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-protonmail.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-ptd.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-q.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-roadrunner.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-rocketmail.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-sbcglobal.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-sc.rr.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-scranton.edu-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-servicios-ta.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-suddenlink.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-twc.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-verizon.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-web.de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-windstream.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-yahoo.co.jp-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-yahoo.co.uk-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-yahoo.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-yahoo.com.mx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-yahoo.de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-yahoo.es-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-yahoo.fr-ker__uid2-Regist_date
# (506691,) | cnt_ratio-P_emaildomain-ymail.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-aim.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-anonymous.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-aol.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-att.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-bellsouth.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-cableone.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-centurylink.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-cfl.rr.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-charter.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-comcast.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-cox.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-earthlink.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-embarqmail.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-frontier.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-frontiernet.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-gmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-gmail.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-gmx.de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-hotmail.co.uk-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-hotmail.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-hotmail.de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-hotmail.es-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-hotmail.fr-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-icloud.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-juno.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-live.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-live.com.mx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-live.fr-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-mac.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-mail.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-me.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-msn.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-netzero.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-netzero.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-optonline.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-outlook.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-outlook.es-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-prodigy.net.mx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-protonmail.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-ptd.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-q.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-roadrunner.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-rocketmail.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-sbcglobal.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-sc.rr.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-scranton.edu-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-servicios-ta.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-suddenlink.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-twc.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-verizon.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-web.de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-windstream.net-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-yahoo.co.jp-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-yahoo.co.uk-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-yahoo.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-yahoo.com.mx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-yahoo.de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-yahoo.es-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-yahoo.fr-ker__uid2-Regist_date
# (590540,) | cnt_ratio-R_emaildomain-ymail.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-aim.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-anonymous.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-aol.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-att.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-bellsouth.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-cableone.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-centurylink.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-cfl.rr.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-charter.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-comcast.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-cox.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-earthlink.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-embarqmail.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-frontier.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-frontiernet.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-gmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-gmail.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-gmx.de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-hotmail.co.uk-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-hotmail.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-hotmail.de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-hotmail.es-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-hotmail.fr-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-icloud.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-juno.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-live.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-live.com.mx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-live.fr-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-mac.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-mail.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-me.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-msn.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-netzero.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-netzero.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-optonline.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-outlook.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-outlook.es-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-prodigy.net.mx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-protonmail.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-ptd.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-q.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-roadrunner.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-rocketmail.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-sbcglobal.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-sc.rr.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-scranton.edu-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-servicios-ta.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-suddenlink.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-twc.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-verizon.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-web.de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-windstream.net-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-yahoo.co.jp-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-yahoo.co.uk-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-yahoo.com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-yahoo.com.mx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-yahoo.de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-yahoo.es-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-yahoo.fr-ker__uid2-Regist_date
# (506691,) | cnt_ratio-R_emaildomain-ymail.com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-aim-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-anonymous-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-aol-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-att-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-bellsouth-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-cableone-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-centurylink-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-cfl-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-charter-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-comcast-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-cox-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-earthlink-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-embarqmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-frontier-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-frontiernet-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-gmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-gmx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-hotmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-icloud-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-juno-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-live-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-mac-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-mail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-me-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-msn-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-netzero-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-optonline-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-outlook-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-prodigy-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-protonmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-ptd-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-q-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-roadrunner-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-rocketmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-sbcglobal-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-sc-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-scranton-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-servicios-ta-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-suddenlink-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-twc-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-verizon-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-web-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-windstream-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-yahoo-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_prefix-ymail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-aim-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-anonymous-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-aol-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-att-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-bellsouth-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-cableone-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-centurylink-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-cfl-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-charter-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-comcast-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-cox-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-earthlink-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-embarqmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-frontier-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-frontiernet-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-gmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-gmx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-hotmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-icloud-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-juno-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-live-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-mac-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-mail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-me-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-msn-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-netzero-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-optonline-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-outlook-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-prodigy-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-protonmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-ptd-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-q-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-roadrunner-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-rocketmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-sbcglobal-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-sc-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-scranton-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-servicios-ta-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-suddenlink-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-twc-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-verizon-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-web-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-windstream-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-yahoo-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_prefix-ymail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-es-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-fr-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-jp-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-mx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-uk-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__P_emaildomain_suffix-us-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-es-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-fr-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-jp-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-mx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-uk-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__P_emaildomain_suffix-us-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-aim-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-anonymous-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-aol-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-att-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-bellsouth-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-cableone-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-centurylink-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-cfl-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-charter-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-comcast-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-cox-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-earthlink-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-embarqmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-frontier-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-frontiernet-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-gmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-gmx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-hotmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-icloud-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-juno-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-live-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-mac-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-mail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-me-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-msn-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-netzero-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-optonline-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-outlook-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-prodigy-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-protonmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-ptd-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-q-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-roadrunner-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-rocketmail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-sbcglobal-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-sc-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-scranton-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-servicios-ta-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-suddenlink-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-twc-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-verizon-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-web-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-windstream-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-yahoo-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_prefix-ymail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-aim-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-anonymous-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-aol-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-att-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-bellsouth-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-cableone-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-centurylink-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-cfl-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-charter-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-comcast-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-cox-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-earthlink-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-embarqmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-frontier-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-frontiernet-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-gmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-gmx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-hotmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-icloud-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-juno-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-live-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-mac-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-mail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-me-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-msn-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-netzero-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-optonline-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-outlook-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-prodigy-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-protonmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-ptd-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-q-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-roadrunner-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-rocketmail-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-sbcglobal-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-sc-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-scranton-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-servicios-ta-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-suddenlink-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-twc-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-verizon-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-web-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-windstream-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-yahoo-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_prefix-ymail-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-#-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-com-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-de-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-es-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-fr-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-jp-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-mx-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-uk-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__R_emaildomain_suffix-us-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-#-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-com-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-de-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-es-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-fr-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-jp-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-mx-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-uk-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__R_emaildomain_suffix-us-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-2-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-80-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-101-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-103-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-106-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-130-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-137-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-140-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-159-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-272-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-277-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-298-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-303-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-311-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-318-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-319-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-323-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-334-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-344-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-362-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-386-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-387-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-397-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-439-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-464-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-468-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-518-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-552-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-574-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-583-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-594-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-627-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-674-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-862-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-863-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-979-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-993-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1105-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1156-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1443-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1470-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1937-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-2657-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-2713-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-2827-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-3437-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-4075-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-5011-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-5720-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-5767-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-7480-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-7647-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-9934-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-12316-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-14474-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-52337-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-71062-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-85649-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-163648-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-182784-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-435803-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-2-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-80-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-101-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-103-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-106-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-130-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-137-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-140-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-159-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-272-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-277-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-298-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-303-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-311-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-318-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-319-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-323-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-334-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-344-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-362-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-386-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-387-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-397-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-439-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-464-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-468-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-518-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-552-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-574-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-583-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-594-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-627-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-674-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-862-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-863-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-979-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-993-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1105-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1156-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1443-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1470-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1937-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-2657-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-2713-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-2827-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-3437-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-4075-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-5011-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-5720-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-5767-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-7480-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-7647-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-9934-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-12316-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-14474-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-52337-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-71062-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-85649-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-163648-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-182784-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-435803-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-14-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-19-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-24-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-28-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-38-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-45-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-46-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-55-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-57-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-61-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-69-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-70-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-75-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-77-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-80-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-82-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-101-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-104-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-105-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-110-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-111-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-124-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-126-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-130-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-139-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-140-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-170-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-196-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-263-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-297-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-303-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-315-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-317-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-341-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-350-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-405-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-430-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-514-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-595-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-667-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-795-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-853-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-854-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-870-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1095-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1163-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1202-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1444-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1464-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1698-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-2743-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-2820-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-3513-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-5011-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-7239-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-21405-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-39644-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-53166-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-118885-ker__uid2-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-824070-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-14-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-19-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-24-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-28-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-38-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-45-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-46-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-55-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-57-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-61-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-69-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-70-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-75-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-77-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-80-ker__uid2-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-82-ker__uid2-Regist_date
# ...
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-387-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-397-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-439-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-464-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-468-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-518-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-552-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-574-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-583-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-594-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-627-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-674-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-862-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-863-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-979-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-993-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1105-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1156-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1443-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1470-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-1937-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-2657-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-2713-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-2827-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-3437-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-4075-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-5011-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-5720-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-5767-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-7480-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-7647-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-9934-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-12316-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-14474-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-52337-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-71062-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-85649-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-163648-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-182784-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_P_emaildomain-435803-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-2-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-80-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-101-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-103-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-106-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-130-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-137-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-140-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-159-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-272-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-277-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-298-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-303-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-311-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-318-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-319-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-323-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-334-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-344-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-362-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-386-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-387-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-397-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-439-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-464-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-468-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-518-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-552-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-574-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-583-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-594-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-627-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-674-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-862-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-863-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-979-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-993-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1105-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1156-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1443-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1470-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-1937-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-2657-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-2713-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-2827-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-3437-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-4075-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-5011-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-5720-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-5767-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-7480-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-7647-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-9934-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-12316-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-14474-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-52337-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-71062-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-85649-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-163648-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-182784-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_P_emaildomain-435803-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-14-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-19-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-24-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-28-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-38-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-45-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-46-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-55-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-57-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-61-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-69-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-70-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-75-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-77-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-80-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-82-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-101-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-104-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-105-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-110-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-111-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-124-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-126-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-130-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-139-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-140-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-170-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-196-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-263-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-297-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-303-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-315-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-317-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-341-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-350-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-405-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-430-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-514-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-595-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-667-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-795-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-853-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-854-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-870-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1095-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1163-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1202-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1444-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1464-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-1698-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-2743-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-2820-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-3513-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-5011-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-7239-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-21405-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-39644-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-53166-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-118885-ker__uid4-Regist_date
# (590540,) | cnt_ratio-fill__cnt_R_emaildomain-824070-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-14-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-19-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-24-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-28-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-38-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-45-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-46-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-55-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-57-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-61-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-69-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-70-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-75-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-77-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-80-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-82-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-101-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-104-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-105-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-110-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-111-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-124-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-126-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-130-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-139-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-140-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-170-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-196-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-263-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-297-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-303-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-315-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-317-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-341-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-350-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-405-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-430-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-514-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-595-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-667-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-795-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-853-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-854-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-870-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-1095-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-1163-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-1202-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-1444-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-1464-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-1698-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-2743-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-2820-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-3513-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-5011-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-7239-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-21405-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-39644-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-53166-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-118885-ker__uid4-Regist_date
# (506691,) | cnt_ratio-fill__cnt_R_emaildomain-824070-ker__uid4-Regist_date

# %%
list_base_key = cols_uid
cat_list = cols_time
dir_save = 'valid_use'

for base_key in list_base_key:
    
    if str(type(base_key)).count('list'):
        pass
    else:
        base_key = [base_key]
        
    base_key += ['Regist_date']
    name_base = '-'.join(base_key)

    base = data[base_key]
    
    for col_cat in cat_list:


        all_cnt = data.groupby(base_key, as_index=False)[col_cat].agg({
            f'count': 'count'
        })

        part_cnt = data.groupby(base_key + [col_cat], as_index=False)[col_cat].agg({
            f'count_cat': 'count'
        })

        tmp = all_cnt.merge(part_cnt[base_key + [f"count_cat", col_cat]], how='inner', on=base_key)

        tmp['cat_ratio'] = tmp['count_cat'] / tmp['count']
        tmp.drop(['count', 'count_cat'], axis=1, inplace=True)

        result = pd.pivot_table(data=tmp, columns=col_cat, index=base_key)
        cols_save = [f"cnt_ratio-{col_cat}-{col[1]}-{name_base}" for col in result.columns]
        result.columns = cols_save
        df_feat = base.merge(result, how='left', on=base_key)

        base_train = df_feat.iloc[:df_train.shape[0]]
        base_test  = df_feat.iloc[df_train.shape[0]:]

        save_feature(base_train[cols_save], '533', dir_save, is_train=True, auto_type=True, list_ignore=COLUMNS_IGNORE)
        save_feature(base_test[cols_save],  '533', dir_save, is_train=False, auto_type=True, list_ignore=COLUMNS_IGNORE)
# Out:
# (590540,) | cnt_ratio-hour-0.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-0.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-1.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-1.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-2.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-2.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-3.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-3.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-4.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-4.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-5.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-5.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-6.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-6.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-7.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-7.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-8.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-8.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-9.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-9.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-10.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-10.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-11.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-11.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-12.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-12.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-13.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-13.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-14.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-14.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-15.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-15.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-16.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-16.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-17.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-17.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-18.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-18.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-19.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-19.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-20.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-20.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-21.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-21.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-22.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-22.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-23.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-23.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-0.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-0.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-1.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-1.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-2.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-2.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-3.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-3.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-4.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-4.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-5.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-5.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-6.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-6.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-7.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-7.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-8.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-8.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-9.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-9.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-10.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-10.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-11.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-11.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-12.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-12.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-13.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-13.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-14.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-14.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-15.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-15.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-16.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-16.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-17.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-17.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-18.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-18.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-19.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-19.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-20.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-20.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-21.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-21.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-22.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-22.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-23.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-hour-23.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-time_zone-0.0-3.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-time_zone-10.5-17.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-time_zone-17.5-21.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-time_zone-22.0-23.5-ker__uid2-Regist_date
# (590540,) | cnt_ratio-time_zone-3.5-6.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-time_zone-6.5-10.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-time_zone-0.0-3.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-time_zone-10.5-17.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-time_zone-17.5-21.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-time_zone-22.0-23.5-ker__uid2-Regist_date
# (506691,) | cnt_ratio-time_zone-3.5-6.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-time_zone-6.5-10.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-hour-0.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-0.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-1.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-1.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-2.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-2.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-3.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-3.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-4.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-4.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-5.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-5.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-6.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-6.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-7.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-7.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-8.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-8.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-9.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-9.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-10.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-10.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-11.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-11.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-12.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-12.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-13.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-13.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-14.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-14.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-15.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-15.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-16.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-16.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-17.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-17.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-18.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-18.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-19.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-19.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-20.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-20.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-21.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-21.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-22.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-22.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-23.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-23.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-0.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-0.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-1.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-1.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-2.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-2.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-3.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-3.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-4.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-4.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-5.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-5.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-6.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-6.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-7.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-7.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-8.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-8.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-9.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-9.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-10.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-10.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-11.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-11.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-12.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-12.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-13.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-13.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-14.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-14.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-15.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-15.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-16.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-16.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-17.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-17.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-18.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-18.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-19.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-19.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-20.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-20.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-21.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-21.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-22.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-22.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-23.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-hour-23.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-time_zone-0.0-3.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-time_zone-10.5-17.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-time_zone-17.5-21.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-time_zone-22.0-23.5-ker__uid3-Regist_date
# (590540,) | cnt_ratio-time_zone-3.5-6.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-time_zone-6.5-10.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-time_zone-0.0-3.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-time_zone-10.5-17.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-time_zone-17.5-21.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-time_zone-22.0-23.5-ker__uid3-Regist_date
# (506691,) | cnt_ratio-time_zone-3.5-6.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-time_zone-6.5-10.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-hour-0.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-0.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-1.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-1.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-2.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-2.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-3.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-3.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-4.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-4.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-5.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-5.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-6.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-6.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-7.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-7.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-8.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-8.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-9.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-9.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-10.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-10.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-11.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-11.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-12.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-12.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-13.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-13.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-14.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-14.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-15.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-15.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-16.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-16.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-17.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-17.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-18.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-18.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-19.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-19.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-20.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-20.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-21.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-21.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-22.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-22.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-23.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-hour-23.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-0.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-0.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-1.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-1.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-2.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-2.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-3.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-3.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-4.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-4.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-5.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-5.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-6.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-6.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-7.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-7.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-8.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-8.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-9.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-9.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-10.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-10.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-11.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-11.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-12.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-12.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-13.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-13.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-14.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-14.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-15.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-15.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-16.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-16.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-17.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-17.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-18.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-18.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-19.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-19.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-20.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-20.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-21.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-21.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-22.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-22.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-23.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-hour-23.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-time_zone-0.0-3.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-time_zone-10.5-17.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-time_zone-17.5-21.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-time_zone-22.0-23.5-ker__uid4-Regist_date
# (590540,) | cnt_ratio-time_zone-3.5-6.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-time_zone-6.5-10.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-time_zone-0.0-3.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-time_zone-10.5-17.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-time_zone-17.5-21.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-time_zone-22.0-23.5-ker__uid4-Regist_date
# (506691,) | cnt_ratio-time_zone-3.5-6.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-time_zone-6.5-10.0-ker__uid4-Regist_date

# %%
list_base_key = cols_uid
cat_list = cols_501
dir_save = 'valid_use'

for base_key in list_base_key:
    
    if str(type(base_key)).count('list'):
        pass
    else:
        base_key = [base_key]
        
    base_key += ['Regist_date']
    name_base = '-'.join(base_key)

    base = data[base_key]
    
    for col_cat in cat_list:


        all_cnt = data.groupby(base_key, as_index=False)[col_cat].agg({
            f'count': 'count'
        })

        part_cnt = data.groupby(base_key + [col_cat], as_index=False)[col_cat].agg({
            f'count_cat': 'count'
        })

        tmp = all_cnt.merge(part_cnt[base_key + [f"count_cat", col_cat]], how='inner', on=base_key)

        tmp['cat_ratio'] = tmp['count_cat'] / tmp['count']
        tmp.drop(['count', 'count_cat'], axis=1, inplace=True)

        result = pd.pivot_table(data=tmp, columns=col_cat, index=base_key)
        cols_save = [f"cnt_ratio-{col_cat}-{col[1]}-{name_base}" for col in result.columns]
        result.columns = cols_save
        df_feat = base.merge(result, how='left', on=base_key)

        base_train = df_feat.iloc[:df_train.shape[0]]
        base_test  = df_feat.iloc[df_train.shape[0]:]

        save_feature(base_train[cols_save], '533', dir_save, is_train=True, auto_type=True, list_ignore=COLUMNS_IGNORE)
        save_feature(base_test[cols_save],  '533', dir_save, is_train=False, auto_type=True, list_ignore=COLUMNS_IGNORE)
# Out:
# (590540,) | cnt_ratio-501__cnt__OS_id_30-19.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__OS_id_30-21.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__OS_id_30-2488.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__OS_id_30-11783.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__OS_id_30-25634.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__OS_id_30-38502.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__OS_id_30-69777.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__OS_id_30-137916.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__OS_id_30-19.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__OS_id_30-21.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__OS_id_30-2488.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__OS_id_30-11783.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__OS_id_30-25634.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__OS_id_30-38502.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__OS_id_30-69777.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__OS_id_30-137916.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-282.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-765.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-2146.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-4374.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-10154.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-14055.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-26003.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-28357.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-50438.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-149566.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-282.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-765.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-2146.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-4374.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-10154.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-14055.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-26003.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-28357.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-50438.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-149566.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_os-304.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_os-9217.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_os-26924.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_os-57521.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_os-59085.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_os-133089.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_os-304.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_os-9217.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_os-26924.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_os-57521.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_os-59085.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_os-133089.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_country-973.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_country-6282.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_country-7197.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_country-29940.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_country-30349.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_country-55073.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_country-156326.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_country-973.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_country-6282.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_country-7197.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_country-29940.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_country-30349.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_country-55073.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_country-156326.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-304.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-650.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-989.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-1156.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-4354.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-7197.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-7619.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-8155.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-10675.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-12330.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-23722.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-25360.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-38502.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-52417.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-92710.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-304.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-650.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-989.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-1156.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-4354.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-7197.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-7619.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-8155.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-10675.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-12330.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-23722.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-25360.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-38502.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-52417.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-92710.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_os-304.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_os-9124.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_os-26922.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_os-57520.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_os-61035.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_os-131235.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_os-304.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_os-9124.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_os-26922.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_os-57520.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_os-61035.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_os-131235.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_15-8178.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_15-22875.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_15-119397.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_15-135690.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_15-8178.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_15-22875.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_15-119397.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_15-135690.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_23-1018.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_23-2010.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_23-7203.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_23-275909.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_23-1018.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_23-2010.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_23-7203.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_23-275909.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_29-8384.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_29-128492.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_29-149264.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_29-8384.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_29-128492.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_29-149264.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-6.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-19.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-21.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-50.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-51.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-59.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-61.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-67.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-75.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-76.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-84.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-86.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-96.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-101.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-106.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-113.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-123.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-135.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-138.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-164.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-165.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-180.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-182.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-198.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-229.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-248.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-265.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-271.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-273.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-292.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-305.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-346.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-356.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-368.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-401.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-424.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-434.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-496.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-539.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-545.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-573.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-614.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-622.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-644.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-677.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-711.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-754.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-818.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-834.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-871.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-954.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1043.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1063.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1151.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1208.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1255.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1310.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1373.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1493.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1610.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1691.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1834.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1848.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-2043.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-2488.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-2575.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-2662.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-2798.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-3254.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-3308.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-3539.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-3573.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-3776.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-3802.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-3824.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-3884.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-6349.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-23478.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-42170.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-137916.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-6.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-19.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-21.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-50.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-51.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-59.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-61.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-67.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-75.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-76.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-84.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-86.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-96.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-101.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-106.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-113.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-123.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-135.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-138.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-164.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-165.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-180.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-182.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-198.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-229.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-248.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-265.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-271.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-273.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-292.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-305.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-346.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-356.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-368.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-401.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-424.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-434.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-496.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-539.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-545.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-573.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-614.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-622.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-644.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-677.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-711.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-754.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-818.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-834.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-871.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-954.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-1043.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-1063.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-1151.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-1208.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-1255.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-1310.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-1373.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-1493.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-1610.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-1691.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-1834.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-1848.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-2043.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-2488.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-2575.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-2662.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-2798.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-3254.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-3308.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-3539.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-3573.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-3776.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-3802.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-3824.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-3884.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-6349.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-23478.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-42170.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-137916.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-1.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-2.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-3.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-4.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-5.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-6.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-7.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-8.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-9.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-10.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-11.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-12.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-13.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-14.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-15.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-16.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-17.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-19.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-20.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-21.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-22.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-23.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-24.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-25.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-26.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-27.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-29.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-31.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-35.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-37.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-40.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-43.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-44.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-45.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-47.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-49.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-51.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-52.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-57.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-58.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-59.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-63.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-65.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-67.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-72.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-75.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-80.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-83.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-84.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-85.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-92.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-96.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-105.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-117.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-130.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-137.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-140.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-143.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-153.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-165.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-166.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-167.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-171.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-190.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-208.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-217.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-232.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-250.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-258.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-261.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-275.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-277.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-285.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-315.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-405.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-454.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-460.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-469.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-551.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-567.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-588.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-791.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-836.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-866.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-870.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-1061.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-1430.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-1875.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-1892.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-2051.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-2407.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-2825.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-3071.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-3176.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-3325.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-3644.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-3704.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-3871.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-4230.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-6556.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-6603.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-8127.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-9113.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-11550.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-15046.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-33742.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-142180.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-1.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-2.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-3.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-4.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-5.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-6.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-7.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-8.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-9.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-10.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-11.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-12.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-13.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-14.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-15.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-16.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-17.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-19.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-20.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-21.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-22.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-23.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-24.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-25.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-26.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-27.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-29.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-31.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-35.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-37.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-40.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-43.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-44.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-45.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-47.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-49.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-51.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-52.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-57.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-58.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-59.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-63.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-65.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-67.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-72.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-75.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-80.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-83.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-84.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-85.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-92.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-96.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-105.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-117.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-130.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-137.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-140.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-143.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-153.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-165.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-166.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-167.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-171.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-190.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-208.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-217.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-232.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-250.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-258.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-261.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-275.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-277.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-285.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-315.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-405.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-454.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-460.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-469.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-551.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-567.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-588.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-791.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-836.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-866.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-870.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-1061.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-1430.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-1875.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-1892.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-2051.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-2407.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-2825.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-3071.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-3176.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-3325.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-3644.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-3704.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-3871.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-4230.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-6556.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-6603.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-8127.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-9113.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-11550.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-15046.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-33742.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-142180.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_34-3.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_34-415.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_34-17377.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_34-132185.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_34-136160.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_34-3.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_34-415.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_34-17377.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_34-132185.0-ker__uid2-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_34-136160.0-ker__uid2-Regist_date
# (590540,) | cnt_ratio-501__cnt__OS_id_30-19.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__OS_id_30-21.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__OS_id_30-2488.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__OS_id_30-11783.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__OS_id_30-25634.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__OS_id_30-38502.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__OS_id_30-69777.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__OS_id_30-137916.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__OS_id_30-19.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__OS_id_30-21.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__OS_id_30-2488.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__OS_id_30-11783.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__OS_id_30-25634.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__OS_id_30-38502.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__OS_id_30-69777.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__OS_id_30-137916.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-282.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-765.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-2146.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-4374.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-10154.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-14055.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-26003.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-28357.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-50438.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_name-149566.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-282.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-765.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-2146.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-4374.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-10154.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-14055.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-26003.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-28357.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-50438.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_name-149566.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_os-304.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_os-9217.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_os-26924.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_os-57521.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_os-59085.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__browser_os-133089.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_os-304.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_os-9217.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_os-26924.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_os-57521.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_os-59085.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__browser_os-133089.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_country-973.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_country-6282.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_country-7197.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_country-29940.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_country-30349.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_country-55073.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_country-156326.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_country-973.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_country-6282.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_country-7197.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_country-29940.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_country-30349.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_country-55073.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_country-156326.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-304.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-650.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-989.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-1156.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-4354.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-7197.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-7619.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-8155.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-10675.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-12330.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-23722.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-25360.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-38502.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-52417.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_name-92710.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-304.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-650.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-989.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-1156.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-4354.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-7197.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-7619.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-8155.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-10675.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-12330.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-23722.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-25360.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-38502.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-52417.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_name-92710.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_os-304.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_os-9124.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_os-26922.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_os-57520.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_os-61035.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__device_os-131235.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_os-304.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_os-9124.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_os-26922.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_os-57520.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_os-61035.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__device_os-131235.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_15-8178.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_15-22875.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_15-119397.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_15-135690.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_15-8178.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_15-22875.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_15-119397.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_15-135690.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_23-1018.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_23-2010.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_23-7203.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_23-275909.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_23-1018.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_23-2010.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_23-7203.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_23-275909.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_29-8384.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_29-128492.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_29-149264.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_29-8384.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_29-128492.0-ker__uid3-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_29-149264.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-6.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-19.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-21.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-50.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-51.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-59.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-61.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-67.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-75.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-76.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-84.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-86.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-96.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-101.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-106.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-113.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-123.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-135.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-138.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-164.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-165.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-180.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-182.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-198.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-229.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-248.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-265.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-271.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-273.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-292.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-305.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-346.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-356.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-368.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-401.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-424.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-434.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-496.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-539.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-545.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-573.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-614.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-622.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-644.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-677.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-711.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-754.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-818.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-834.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-871.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-954.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1043.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1063.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1151.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1208.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1255.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1310.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1373.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1493.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1610.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1691.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1834.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-1848.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-2043.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-2488.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-2575.0-ker__uid3-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_30-2662.0-ker__uid3-Regist_date
# ...
# (506691,) | cnt_ratio-501__cnt__id_30-1848.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-2043.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-2488.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-2575.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-2662.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-2798.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-3254.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-3308.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-3539.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-3573.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-3776.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-3802.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-3824.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-3884.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-6349.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-23478.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-42170.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_30-137916.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-1.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-2.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-3.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-4.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-5.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-6.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-7.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-8.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-9.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-10.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-11.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-12.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-13.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-14.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-15.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-16.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-17.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-19.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-20.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-21.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-22.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-23.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-24.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-25.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-26.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-27.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-29.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-31.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-35.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-37.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-40.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-43.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-44.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-45.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-47.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-49.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-51.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-52.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-57.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-58.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-59.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-63.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-65.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-67.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-72.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-75.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-80.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-83.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-84.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-85.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-92.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-96.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-105.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-117.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-130.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-137.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-140.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-143.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-153.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-165.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-166.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-167.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-171.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-190.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-208.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-217.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-232.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-250.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-258.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-261.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-275.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-277.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-285.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-315.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-405.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-454.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-460.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-469.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-551.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-567.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-588.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-791.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-836.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-866.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-870.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-1061.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-1430.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-1875.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-1892.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-2051.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-2407.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-2825.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-3071.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-3176.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-3325.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-3644.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-3704.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-3871.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-4230.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-6556.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-6603.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-8127.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-9113.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-11550.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-15046.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-33742.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_33-142180.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-1.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-2.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-3.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-4.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-5.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-6.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-7.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-8.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-9.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-10.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-11.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-12.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-13.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-14.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-15.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-16.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-17.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-19.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-20.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-21.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-22.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-23.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-24.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-25.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-26.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-27.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-29.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-31.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-35.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-37.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-40.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-43.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-44.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-45.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-47.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-49.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-51.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-52.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-57.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-58.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-59.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-63.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-65.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-67.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-72.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-75.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-80.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-83.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-84.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-85.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-92.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-96.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-105.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-117.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-130.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-137.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-140.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-143.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-153.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-165.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-166.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-167.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-171.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-190.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-208.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-217.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-232.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-250.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-258.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-261.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-275.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-277.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-285.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-315.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-405.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-454.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-460.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-469.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-551.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-567.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-588.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-791.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-836.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-866.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-870.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-1061.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-1430.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-1875.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-1892.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-2051.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-2407.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-2825.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-3071.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-3176.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-3325.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-3644.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-3704.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-3871.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-4230.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-6556.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-6603.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-8127.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-9113.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-11550.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-15046.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-33742.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_33-142180.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_34-3.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_34-415.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_34-17377.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_34-132185.0-ker__uid4-Regist_date
# (590540,) | cnt_ratio-501__cnt__id_34-136160.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_34-3.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_34-415.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_34-17377.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_34-132185.0-ker__uid4-Regist_date
# (506691,) | cnt_ratio-501__cnt__id_34-136160.0-ker__uid4-Regist_date
