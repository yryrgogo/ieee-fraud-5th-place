# %%
# %load_ext autoreload
# %autoreload 2
from glob import glob
import gc
import os
import sys
import datetime
import numpy as np
import pandas as pd
from tqdm import tqdm
from func.utils import get_numeric_features, get_categorical_features, read_pkl_gzip, to_pkl_gzip, parallel_load_data, get_filename
from func.time_utils import date_add_days
from func.ml_utils import save_feature, get_cnt_feature, get_dummie_feature, get_label_feature
from func.parallel_utils import get_parallel_arg_list
from joblib import delayed, Parallel

# %%
COLUMN_ID = 'TransactionID'
COLUMN_DT = 'TransactionDT'
COLUMN_TARGET = 'isFraud'
COLUMNS_IGNORE = [COLUMN_ID, COLUMN_DT, COLUMN_TARGET, 'ProductCD']

train_paths = glob('../feature/eda_base/*_train.gz')
test_paths = glob('../feature/eda_base/*_test.gz')

train_paths = [path for path in train_paths 
               if path.count(COLUMN_DT) 
               or path.count(COLUMN_ID)
               or path.count('time_zone')
               or path.count('hour')
               or path.count('C')
               or path.count('D')
               or path.count('Product')
              ]
test_paths = [path for path in test_paths 
               if path.count(COLUMN_DT) 
               or path.count(COLUMN_ID)
               or path.count('time_zone')
               or path.count('hour')
               or path.count('C')
               or path.count('D')
               or path.count('Product')
              ]

df_train = parallel_load_data(train_paths)
df_test = parallel_load_data(test_paths)
data = pd.concat([df_train, df_test], axis=0, ignore_index=True)
if COLUMN_ID in data.columns:
    data.set_index(COLUMN_ID, inplace=True)

base_train = read_pkl_gzip('../input/base_train.gz').set_index(COLUMN_ID)
base_test = read_pkl_gzip('../input/base_test.gz').set_index(COLUMN_ID)
base = pd.concat([base_train, base_test], axis=0)

cols_num = get_numeric_features(data, COLUMNS_IGNORE)
cols_num = [col for col in cols_num if col.count('C') or col.count('D')]
data[cols_num] = data[cols_num].astype('float32')

df_user_id_ca = pd.read_csv('../output/same_user_pattern/0903__same_user_id__card_addr.csv').set_index(COLUMN_ID)
df_user_id_cap = pd.read_csv('../output/same_user_pattern/0903__same_user_id__card_addr_pemail.csv').set_index(COLUMN_ID)
df_user_id_capm = pd.read_csv('../output/same_user_pattern/0902__same_user_id__card_addr_pemail_M.csv').set_index(COLUMN_ID)
df_user_id_bear = pd.read_csv('../output/same_user_pattern/20190901_user_ids_share.csv').set_index(COLUMN_ID)

data['user_id_card_addr'] = df_user_id_ca['predicted_user_id']
data['user_id_card_addr_pemail'] = df_user_id_cap['predicted_user_id']
data['user_id_card_addr_pemail_M'] = df_user_id_capm['predicted_user_id']
data['user_id_bear'] = df_user_id_bear['predicted_user_id']

# %%
START_DATE = '2017-12-01'
startdate = datetime.datetime.strptime(START_DATE, '%Y-%m-%d')

data['datetime'] = data['TransactionDT'].apply(lambda x: (startdate + datetime.timedelta(seconds = x) - datetime.timedelta(seconds = 14400) ))
data['datetime'].fillna(datetime.date(2020, 1, 1), inplace=True)
data['date'] = data['datetime'].map(lambda x: x.date())

# %%
#========================================================================
# ProductCDあたりのC
#========================================================================
cols_C = [col for col in data.columns if col.startswith('C')]
cols_pcd = data['ProductCD'].unique()

for col in tqdm(cols_C):
    for pcd in cols_pcd:
        feature_name = f'{col}__ProductCD-{pcd}'
        data[feature_name] = -1
        data.loc[data['ProductCD'].isin([pcd]), feature_name] = data.loc[data['ProductCD'].isin([pcd]), col]
# Out:
# 100%|██████████| 14/14 [00:10<00:00,  1.08s/it]

# %%
# sorted([col for col in data.columns if not col.count('C')])
cols_C = sorted([col for col in data.columns if col.count('C') and col not in COLUMNS_IGNORE
#                  and not col.count('Product')
                ])
# cols_D = ['D3', 'D5', 'D6', 'D7', 'D8', 'D9', 'D11', 'D12', 'D13', 'D14']
# cols_feature = cols_C + cols_D
# cols_feature = cols_feature[:3]
len(cols_C)
# Out:
# 84

# %%
#========================================================================
# FE Aggregation User ID & TimeSeries Date
#========================================================================

def parallel_agg(df, base_key, base_date, n_day, feature):
    result = df.groupby(base_key)[feature].agg({
        f'{base_key}_day{n_day}_{feature}_mean': 'mean',
    })
    return result


def parallel_agg(df, base_key, n_day, feature):
    list_term_df = []
    for end_date in tqdm(list_end_date):
        start_date = date_add_days(end_date, n_day*-1)
        tmp_user = df[df['date']==end_date][[base_key]].drop_duplicates()
        
        if n_day>0:
            tmp = df[(start_date <= df.date) & (df.date <= end_date)]
        else:
            tmp = df[(end_date <= df.date) & (df.date <= start_date)]

        result = tmp.groupby(base_key, as_index=False)[feature].agg({
            f'{base_key}_day{n_day}_{feature}_mean': 'mean',
        })

        tmp_user = tmp_user.merge(result, on=base_key, how='inner')
        tmp_user['date'] = end_date
        list_term_df.append(tmp_user)
    df_agg = pd.concat(list_term_df, axis=0)
    df_agg.set_index([base_key, 'date'], inplace=True)
    return df_agg
    

# User別に期間を切って集計できる様にする
dir_save = 'valid'
df = data
list_base_key = [col for col in df.columns if col.count('user_id')]
list_end_date = sorted(df['date'].unique())[:-1]
list_base_date = list_end_date
# list_n_day = [1, 3, 5, 7, 10, 14, 21, 28, 31, 62, 93, 124, 180, 270, 360][1:]
list_n_day = [-1, -3, -5, -7, -14, -21, -31]
# list_n_day = [1, 3, 5, 7, 10, 14]

for base_key in list_base_key:
    for feature in cols_C:
        
        base_train = data[[base_key, 'date', feature]].iloc[:len(df_train)]
        base_test  = data[[base_key, 'date', feature]].iloc[len(df_train):]
        
        list_p = Parallel(60)([delayed(parallel_agg)(df[[base_key, 'date', feature]], base_key, n_day, feature) for n_day in list_n_day])
        
        df_agg = pd.concat(list_p, axis=1)
        df_agg.reset_index(inplace=True)
        df_agg['date'] = df_agg['date'].map(lambda x: x.date())
            
        base_train_agg = base_train.merge(df_agg, how='left', on=[base_key, 'date'])
        base_test_agg = base_test.merge(df_agg, how='left', on=[base_key, 'date'])
        
        cols_agg = [col for col in base_train_agg.columns if col.count(f'{base_key}_day')]
        
        for col in cols_agg:
            base_train_agg[f"{col}_org_ratio"] = base_train_agg[col] / (base_train_agg[feature]+1)
            base_train_agg[f"{col}_org_diff"] = base_train_agg[col] - (base_train_agg[feature])
            base_test_agg[f"{col}_org_ratio"] = base_test_agg[col] / (base_test_agg[feature]+1)
            base_test_agg[f"{col}_org_diff"] = base_test_agg[col] - (base_test_agg[feature])
        
        cols_save = [col for col in base_train_agg.columns if col.count('org_ratio') or col.count('org_diff')]
        
        save_feature(base_train_agg[cols_save], '503', dir_save, is_train=True, auto_type=True, list_ignore=COLUMNS_IGNORE)
        save_feature(base_test_agg[cols_save],  '503', dir_save, is_train=False, auto_type=True, list_ignore=COLUMNS_IGNORE)
# Out:
# (590540,) | user_id_card_addr_day-1_C1_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C1_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C1_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C1_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C1_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C1_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C1_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C1_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C1_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C1_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C1_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C1_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C1_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C1_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C1_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C1_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C1_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C1_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C1_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C1_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C1_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C1_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C1_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C1_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C1_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C1_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C1_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C1_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C10_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C10_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C10_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C10_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C10_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C10_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C10_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C10_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C10_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C10_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C10_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C10_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C10_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C10_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C10_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C10_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C10_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C10_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C10_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C10_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C10_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C10_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C10_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C10_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C10_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C10_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C10_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C10_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C10__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C10__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C10__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C10__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C10__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C10__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C10__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C10__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C10__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C10__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C10__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C10__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C10__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C10__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C10__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C10__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C10__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C10__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C10__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C10__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C10__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C10__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C10__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C10__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C10__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C10__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C10__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C10__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C10__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C10__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C10__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C10__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C10__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C10__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C10__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C10__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C10__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C10__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C10__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C10__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C10__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C10__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C10__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C10__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C10__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C10__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C10__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C10__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C10__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C10__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C10__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C10__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C10__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C10__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C10__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C10__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C10__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C10__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C10__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C10__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C10__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C10__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C10__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C10__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C10__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C10__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C10__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C10__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C10__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C10__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C10__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C10__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C10__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C10__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C10__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C10__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C10__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C10__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C10__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C10__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C10__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C10__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C10__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C10__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C10__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C10__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C10__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C10__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C10__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C10__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C10__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C10__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C10__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C10__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C10__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C10__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C10__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C10__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C10__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C10__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C10__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C10__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C10__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C10__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C10__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C10__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C10__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C10__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C10__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C10__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C10__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C10__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C10__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C10__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C10__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C10__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C10__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C10__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C10__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C10__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C10__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C10__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C10__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C10__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C10__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C10__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C10__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C10__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C10__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C10__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C10__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C10__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C10__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C10__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C10__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C10__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C10__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C10__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C10__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C10__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C11_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C11_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C11_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C11_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C11_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C11_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C11_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C11_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C11_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C11_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C11_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C11_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C11_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C11_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C11_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C11_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C11_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C11_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C11_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C11_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C11_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C11_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C11_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C11_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C11_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C11_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C11_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C11_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C11__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C11__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C11__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C11__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C11__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C11__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C11__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C11__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C11__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C11__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C11__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C11__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C11__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C11__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C11__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C11__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C11__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C11__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C11__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C11__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C11__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C11__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C11__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C11__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C11__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C11__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C11__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C11__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C11__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C11__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C11__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C11__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C11__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C11__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C11__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C11__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C11__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C11__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C11__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C11__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C11__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C11__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C11__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C11__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C11__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C11__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C11__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C11__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C11__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C11__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C11__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C11__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C11__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C11__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C11__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C11__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C11__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C11__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C11__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C11__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C11__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C11__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C11__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C11__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C11__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C11__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C11__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C11__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C11__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C11__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C11__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C11__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C11__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C11__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C11__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C11__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C11__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C11__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C11__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C11__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C11__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C11__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C11__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C11__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C11__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C11__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C11__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C11__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C11__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C11__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C11__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C11__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C11__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C11__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C11__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C11__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C11__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C11__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C11__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C11__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C11__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C11__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C11__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C11__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C11__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C11__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C11__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C11__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C11__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C11__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C11__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C11__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C11__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C11__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C11__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C11__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C11__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C11__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C11__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C11__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C11__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C11__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C11__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C11__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C11__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C11__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C11__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C11__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C11__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C11__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C11__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C11__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C11__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C11__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C11__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C11__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C11__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C11__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C11__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C11__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C12_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C12_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C12_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C12_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C12_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C12_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C12_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C12_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C12_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C12_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C12_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C12_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C12_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C12_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C12_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C12_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C12_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C12_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C12_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C12_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C12_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C12_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C12_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C12_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C12_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C12_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C12_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C12_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C12__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C12__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C12__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C12__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C12__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C12__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C12__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C12__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C12__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C12__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C12__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C12__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C12__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C12__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C12__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C12__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C12__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C12__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C12__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C12__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C12__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C12__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C12__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C12__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C12__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C12__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C12__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C12__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C12__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C12__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C12__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C12__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C12__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C12__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C12__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C12__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C12__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C12__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C12__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C12__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C12__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C12__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C12__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C12__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C12__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C12__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C12__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C12__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C12__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C12__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C12__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C12__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C12__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C12__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C12__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C12__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C12__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C12__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C12__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C12__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C12__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C12__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C12__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C12__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C12__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C12__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C12__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C12__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C12__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C12__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C12__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C12__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C12__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C12__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C12__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C12__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C12__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C12__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C12__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C12__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C12__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C12__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C12__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C12__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C12__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C12__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C12__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C12__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C12__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C12__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C12__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C12__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C12__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C12__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C12__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C12__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C12__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C12__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C12__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C12__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C12__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C12__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C12__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C12__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C12__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C12__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C12__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C12__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C12__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C12__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C12__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C12__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C12__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C12__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C12__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C12__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C12__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C12__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C12__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C12__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C12__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C12__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C12__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C12__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C12__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C12__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C12__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C12__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C12__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C12__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C12__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C12__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C12__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C12__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C12__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C12__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C12__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C12__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C12__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C12__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C13_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C13_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C13_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C13_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C13_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C13_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C13_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C13_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C13_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C13_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C13_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C13_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C13_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C13_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C13_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C13_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C13_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C13_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C13_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C13_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C13_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C13_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C13_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C13_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C13_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C13_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C13_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C13_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C13__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C13__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C13__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C13__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C13__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C13__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C13__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C13__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C13__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C13__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C13__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C13__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C13__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C13__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C13__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C13__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C13__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C13__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C13__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C13__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C13__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C13__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C13__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C13__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C13__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C13__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C13__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C13__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C13__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C13__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C13__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C13__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C13__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C13__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C13__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C13__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C13__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C13__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C13__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C13__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C13__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C13__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C13__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C13__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C13__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C13__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C13__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C13__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C13__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C13__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C13__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C13__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C13__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C13__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C13__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C13__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C13__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C13__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C13__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C13__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C13__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C13__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C13__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C13__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C13__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C13__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C13__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C13__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C13__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C13__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C13__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C13__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C13__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C13__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C13__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C13__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C13__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C13__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C13__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C13__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C13__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C13__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C13__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C13__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C13__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C13__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C13__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C13__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C13__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C13__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C13__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C13__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C13__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C13__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C13__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C13__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C13__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C13__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C13__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C13__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C13__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C13__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C13__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C13__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C13__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C13__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C13__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C13__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C13__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C13__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C13__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C13__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C13__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C13__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C13__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C13__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C13__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C13__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C13__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C13__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C13__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C13__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C13__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C13__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C13__ProductCD-W_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C13__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C13__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C13__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C13__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C13__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C13__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C13__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C13__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C13__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C13__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C13__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C13__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C13__ProductCD-W_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C13__ProductCD-W_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C13__ProductCD-W_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C14_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C14_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C14_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C14_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C14_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C14_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C14_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C14_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C14_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C14_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C14_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C14_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C14_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C14_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C14_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C14_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C14_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C14_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C14_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C14_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C14_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C14_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C14_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C14_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C14_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C14_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C14_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C14_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C14__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C14__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C14__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C14__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C14__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C14__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C14__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C14__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C14__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C14__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C14__ProductCD-C_mean_org_ratio
# ...
# (590540,) | user_id_card_addr_day-7_C5_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C5_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C5_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C5_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C5_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C5_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C5_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C5_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C5_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C5_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C5_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C5_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C5_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C5_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C5_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C5_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C5_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C5_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C5_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C5_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C5_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C5_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C5__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C5__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C5__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C5__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C5__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C5__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C5__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C5__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C5__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C5__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C5__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C5__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C5__ProductCD-C_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C5__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C5__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C5__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C5__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C5__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C5__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C5__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C5__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C5__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C5__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C5__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C5__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C5__ProductCD-C_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C5__ProductCD-C_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C5__ProductCD-C_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C5__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C5__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C5__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C5__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C5__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C5__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C5__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C5__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C5__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C5__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C5__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C5__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C5__ProductCD-H_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C5__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C5__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C5__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C5__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C5__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C5__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C5__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C5__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C5__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C5__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C5__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C5__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C5__ProductCD-H_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C5__ProductCD-H_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C5__ProductCD-H_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C5__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C5__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C5__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C5__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C5__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C5__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C5__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C5__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C5__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C5__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C5__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C5__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C5__ProductCD-R_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C5__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C5__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C5__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C5__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C5__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C5__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C5__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C5__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C5__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C5__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C5__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C5__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C5__ProductCD-R_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C5__ProductCD-R_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C5__ProductCD-R_mean_org_diff
# (590540,) | user_id_card_addr_day-1_C5__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-1_C5__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-3_C5__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-3_C5__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-5_C5__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-5_C5__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-7_C5__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-7_C5__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-14_C5__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-14_C5__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-21_C5__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-21_C5__ProductCD-S_mean_org_diff
# (590540,) | user_id_card_addr_day-31_C5__ProductCD-S_mean_org_ratio
# (590540,) | user_id_card_addr_day-31_C5__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-1_C5__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-1_C5__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-3_C5__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-3_C5__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-5_C5__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-5_C5__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-7_C5__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-7_C5__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-14_C5__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-14_C5__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-21_C5__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-21_C5__ProductCD-S_mean_org_diff
# (506691,) | user_id_card_addr_day-31_C5__ProductCD-S_mean_org_ratio
# (506691,) | user_id_card_addr_day-31_C5__ProductCD-S_mean_org_diff
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/yryrgogo/anaconda3/lib/python3.7/site-packages/joblib/externals/loky/backend/queues.py", line 150, in _feed
#     obj_ = dumps(obj, reducers=reducers)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/site-packages/joblib/externals/loky/backend/reduction.py", line 243, in dumps
#     dump(obj, buf, reducers=reducers, protocol=protocol)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/site-packages/joblib/externals/loky/backend/reduction.py", line 236, in dump
#     _LokyPickler(file, reducers=reducers, protocol=protocol).dump(obj)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/site-packages/joblib/externals/cloudpickle/cloudpickle.py", line 267, in dump
#     return Pickler.dump(self, obj)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 437, in dump
#     self.save(obj)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 662, in save_reduce
#     save(state)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 662, in save_reduce
#     save(state)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 887, in _batch_setitems
#     save(v)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 662, in save_reduce
#     save(state)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 816, in save_list
#     self._batch_appends(obj)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 843, in _batch_appends
#     save(tmp[0])
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 771, in save_tuple
#     save(element)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 786, in save_tuple
#     save(element)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 662, in save_reduce
#     save(state)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 662, in save_reduce
#     save(state)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 786, in save_tuple
#     save(element)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 816, in save_list
#     self._batch_appends(obj)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 840, in _batch_appends
#     save(x)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/pickle.py", line 510, in save
#     rv = reduce(obj)
#   File "/home/yryrgogo/anaconda3/lib/python3.7/site-packages/joblib/_memmapping_reducer.py", line 361, in __call__
#     return (loads, (dumps(a, protocol=HIGHEST_PROTOCOL),))
# MemoryError
# """
#
# The above exception was the direct cause of the following exception:
#
# PicklingError                             Traceback (most recent call last)
# <ipython-input-7-2c2a90d8ba20> in <module>
#      49         base_test  = data[[base_key, 'date', feature]].iloc[len(df_train):]
#      50
# ---> 51         list_p = Parallel(60)([delayed(parallel_agg)(df[[base_key, 'date', feature]], base_key, n_day, feature) for n_day in list_n_day])
#      52
#      53         df_agg = pd.concat(list_p, axis=1)
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     932
#     933             with self._backend.retrieval_context():
# --> 934                 self.retrieve()
#     935             # Make sure that we get a last message telling us we are done
#     936             elapsed_time = time.time() - self._start_time
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# ~/anaconda3/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     423                 raise CancelledError()
#     424             elif self._state == FINISHED:
# --> 425                 return self.__get_result()
#     426
#     427             self._condition.wait(timeout)
#
# ~/anaconda3/lib/python3.7/concurrent/futures/_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# PicklingError: Could not pickle the task to send it to the workers.

# %%
### ========================================================================
# FE Aggregation User ID & TimeSeries Hour
#========================================================================
# list_base_key
# Out:
# 1
