# %% [markdown]
# Create Train Log Table in BigQuery

# %%
from func.BigQuery import BigQuery
from bq_log import create_train_log_table, create_new_log_value

# %%
bq = BigQuery('dim_ml_dataset')
bq.del_table('ieee__train_log')
create_train_log_table(bq)

# %%
n_features = len(use_cols)
n_rows = df_train.shape[0]
save_log_cv_result(cv_score, feim_df, model_type, n_features, n_rows, params, pred_result, score_list, adv_cv_score)
