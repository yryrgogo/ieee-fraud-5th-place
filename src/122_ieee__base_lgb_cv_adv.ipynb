# %%
# %load_ext autoreload
# %autoreload 2
from glob import glob
import os
from pathlib import Path
import re
import sys
import yaml
import datetime
import numpy as np
import pandas as pd
from sklearn.model_selection import GroupKFold
from tqdm import tqdm
from func.BigQuery import BigQuery
from func.utils import get_categorical_features, read_pkl_gzip, to_pkl_gzip, parallel_load_data, get_filename
from func.ml_utils import Classifier, drop_unique_feature, drop_high_corr_feature, save_feature
from ieee_utils import ieee_cv, save_log_cv_result, valid_submit_prediction
from func.preprocessing import get_dummies
from kaggle_utils import reduce_mem_usage, move_feature
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
COLUMN_ID = 'TransactionID'
COLUMN_DT = 'TransactionDT'
COLUMN_TARGET = 'isFraud'
COLUMNS_IGNORE = [COLUMN_ID, COLUMN_DT, COLUMN_TARGET]

paths_train = glob('../feature/raw_use/*_train.gz')
paths_test = glob('../feature/raw_use/*_test.gz')

paths_train = [path for path in paths_train 
               if path.count('Fraud') 
               or path.count(COLUMN_ID)
               or path.count('D')
               or path.count('C')
               or path.count('V')
               or path.count('amt')
               or path.count('card')
               or path.count('addr')
#                or path.count('Reg')
               or path.count('P_email')
               or path.count('R_email')
               or path.count('M')
               or path.count('Product')
              ]
paths_test  = [path for path in paths_test  
               if path.count('Fraud') 
               or path.count(COLUMN_ID)
               or path.count('D')
               or path.count('C')
               or path.count('V')
               or path.count('amt')
               or path.count('card')
               or path.count('addr')
#                or path.count('Reg')
               or path.count('P_email')
               or path.count('R_email')
               or path.count('M')
               or path.count('Product')
              ]

df_train = reduce_mem_usage( parallel_load_data(paths_train) )
df_test  = reduce_mem_usage( parallel_load_data(paths_test) )
# Out:
# Memory usage of dataframe is 298.49 MB
# Memory usage after optimization is: 308.06 MB
# Decreased by -3.2%
# Memory usage of dataframe is 478.39 MB
# Memory usage after optimization is: 541.20 MB
# Decreased by -13.1%

# %%
# Categorical Encode
cols_cat = get_categorical_features(df=df_train, ignore_list=COLUMNS_IGNORE)
df_train = get_dummies(df_train, cols_cat)
df_test  = get_dummies(df_test, cols_cat)

# %%
# Save raw features
save_feature(df_train, prefix='raw', dir_save='raw_use', is_train=True, auto_type=False, list_ignore=COLUMNS_IGNORE)
save_feature(df_test, prefix='raw', dir_save='raw_use', is_train=False, auto_type=False, list_ignore=COLUMNS_IGNORE, is_viz=False)
# Out:
# (590540,) | D15
# (590540,) | V327
# (590540,) | V7
# (590540,) | V147
# (590540,) | V210
# (590540,) | V225
# (590540,) | V106
# (590540,) | V203
# (590540,) | V3
# (590540,) | V61
# (590540,) | V323
# (590540,) | V110
# (590540,) | V252
# (590540,) | V170
# (590540,) | V104
# (590540,) | V98
# (590540,) | D2
# (590540,) | V176
# (590540,) | V77
# (590540,) | V33
# (590540,) | V62
# (590540,) | C12
# (590540,) | V171
# (590540,) | V237
# (590540,) | V166
# (590540,) | V35
# (590540,) | V319
# (590540,) | V135
# (590540,) | V261
# (590540,) | V183
# (590540,) | V313
# (590540,) | V105
# (590540,) | V88
# (590540,) | V59
# (590540,) | V278
# (590540,) | C1
# (590540,) | V15
# (590540,) | V260
# (590540,) | D6
# (590540,) | V148
# (590540,) | V227
# (590540,) | V333
# (590540,) | V236
# (590540,) | V22
# (590540,) | V276
# (590540,) | V144
# (590540,) | V68
# (590540,) | V126
# (590540,) | V238
# (590540,) | C6
# (590540,) | V63
# (590540,) | V289
# (590540,) | V308
# (590540,) | V275
# (590540,) | V173
# (590540,) | V266
# (590540,) | V140
# (590540,) | V254
# (590540,) | V221
# (590540,) | D10
# (590540,) | V149
# (590540,) | V45
# (590540,) | D4
# (590540,) | V271
# (590540,) | V32
# (590540,) | V136
# (590540,) | V273
# (590540,) | V247
# (590540,) | V296
# (590540,) | V161
# (590540,) | V241
# (590540,) | V37
# (590540,) | V206
# (590540,) | V16
# (590540,) | V217
# (590540,) | V169
# (590540,) | V130
# (590540,) | V331
# (590540,) | V208
# (590540,) | V189
# (590540,) | V17
# (590540,) | V118
# (590540,) | V89
# (590540,) | V311
# (590540,) | V112
# (590540,) | C14
# (590540,) | V205
# (590540,) | V201
# (590540,) | V234
# (590540,) | V224
# (590540,) | V218
# (590540,) | V83
# (590540,) | V321
# (590540,) | V180
# (590540,) | V111
# (590540,) | V198
# (590540,) | V179
# (590540,) | V90
# (590540,) | V65
# (590540,) | V23
# (590540,) | V235
# (590540,) | V207
# (590540,) | card2
# (590540,) | V116
# (590540,) | V186
# (590540,) | V316
# (590540,) | C13
# (590540,) | V298
# (590540,) | V108
# (590540,) | card5
# (590540,) | V29
# (590540,) | V175
# (590540,) | V239
# (590540,) | V215
# (590540,) | V167
# (590540,) | C3
# (590540,) | card1
# (590540,) | D5
# (590540,) | D14
# (590540,) | V184
# (590540,) | V223
# (590540,) | V129
# (590540,) | V117
# (590540,) | V143
# (590540,) | V325
# (590540,) | V196
# (590540,) | V5
# (590540,) | V156
# (590540,) | V150
# (590540,) | V82
# (590540,) | V38
# (590540,) | V256
# (590540,) | addr2
# (590540,) | V288
# (590540,) | V44
# (590540,) | V160
# (590540,) | V21
# (590540,) | V73
# (590540,) | V306
# (590540,) | V34
# (590540,) | V122
# (590540,) | V64
# (590540,) | V314
# (590540,) | V187
# (590540,) | V339
# (590540,) | V94
# (590540,) | V131
# (590540,) | V159
# (590540,) | V139
# (590540,) | V326
# (590540,) | V4
# (590540,) | V69
# (590540,) | V230
# (590540,) | V312
# (590540,) | V307
# (590540,) | V152
# (590540,) | V11
# (590540,) | V19
# (590540,) | V146
# (590540,) | V259
# (590540,) | V185
# (590540,) | V213
# (590540,) | V20
# (590540,) | V301
# (590540,) | V84
# (590540,) | C9
# (590540,) | V157
# (590540,) | C7
# (590540,) | V309
# (590540,) | V257
# (590540,) | V279
# (590540,) | V164
# (590540,) | V329
# (590540,) | V178
# (590540,) | V154
# (590540,) | V9
# (590540,) | V181
# (590540,) | V142
# (590540,) | V165
# (590540,) | V270
# (590540,) | V39
# (590540,) | V132
# (590540,) | V120
# (590540,) | V192
# (590540,) | V95
# (590540,) | V109
# (590540,) | V48
# (590540,) | V123
# (590540,) | V338
# (590540,) | V295
# (590540,) | V324
# (590540,) | C4
# (590540,) | V220
# (590540,) | V190
# (590540,) | C11
# (590540,) | V54
# (590540,) | V280
# (590540,) | V67
# (590540,) | V336
# (590540,) | V222
# (590540,) | D11
# (590540,) | V287
# (590540,) | V40
# (590540,) | V328
# (590540,) | V204
# (590540,) | V174
# (590540,) | V242
# (590540,) | V317
# (590540,) | V115
# (590540,) | V191
# (590540,) | V49
# (590540,) | V47
# (590540,) | V153
# (590540,) | V233
# (590540,) | V195
# (590540,) | V86
# (590540,) | V79
# (590540,) | V245
# (590540,) | V52
# (590540,) | V229
# (590540,) | V101
# (590540,) | V1
# (590540,) | V168
# (590540,) | V300
# (590540,) | V113
# (590540,) | V283
# (590540,) | V53
# (590540,) | addr1
# (590540,) | V50
# (590540,) | V134
# (590540,) | V244
# (590540,) | V318
# (590540,) | V66
# (590540,) | V177
# (590540,) | V80
# (590540,) | V75
# (590540,) | V282
# (590540,) | V194
# (590540,) | V248
# (590540,) | D3
# (590540,) | V28
# (590540,) | V292
# (590540,) | V55
# (590540,) | V81
# (590540,) | V172
# (590540,) | V231
# (590540,) | D9
# (590540,) | V226
# (590540,) | V182
# (590540,) | V251
# (590540,) | V36
# (590540,) | V121
# (590540,) | V56
# (590540,) | V250
# (590540,) | V249
# (590540,) | V8
# (590540,) | V102
# (590540,) | V12
# (590540,) | V274
# (590540,) | V42
# (590540,) | V162
# (590540,) | V70
# (590540,) | V320
# (590540,) | V30
# (590540,) | V202
# (590540,) | V151
# (590540,) | V193
# (590540,) | V27
# (590540,) | V158
# (590540,) | V141
# (590540,) | V258
# (590540,) | V294
# (590540,) | V87
# (590540,) | V57
# (590540,) | V255
# (590540,) | V145
# (590540,) | V310
# (590540,) | V335
# (590540,) | V228
# (590540,) | V197
# (590540,) | V97
# (590540,) | V107
# (590540,) | V334
# (590540,) | V99
# (590540,) | V24
# (590540,) | V155
# (590540,) | V78
# (590540,) | V322
# (590540,) | V332
# (590540,) | D1
# (590540,) | V85
# (590540,) | V281
# (590540,) | V219
# (590540,) | V92
# (590540,) | V232
# (590540,) | C2
# (590540,) | V60
# (590540,) | V212
# (590540,) | V93
# (590540,) | V128
# (590540,) | C8
# (590540,) | V240
# (590540,) | V269
# (590540,) | V293
# (590540,) | V262
# (590540,) | V76
# (590540,) | V6
# (590540,) | V268
# (590540,) | V119
# (590540,) | V43
# (590540,) | V291
# (590540,) | V127
# (590540,) | V277
# (590540,) | V243
# (590540,) | V163
# (590540,) | V26
# (590540,) | V25
# (590540,) | V284
# (590540,) | V246
# (590540,) | V41
# (590540,) | V200
# (590540,) | V253
# (590540,) | V74
# (590540,) | V31
# (590540,) | V285
# (590540,) | V209
# (590540,) | C10
# (590540,) | D12
# (590540,) | V71
# (590540,) | V265
# (590540,) | V299
# (590540,) | V14
# (590540,) | V302
# (590540,) | C5
# (590540,) | V263
# (590540,) | V10
# (590540,) | V216
# (590540,) | V297
# (590540,) | V137
# (590540,) | V214
# (590540,) | V337
# (590540,) | V188
# (590540,) | V199
# (590540,) | V103
# (590540,) | V58
# (590540,) | card3
# (590540,) | V290
# (590540,) | V100
# (590540,) | V133
# (590540,) | V51
# (590540,) | V72
# (590540,) | V125
# (590540,) | D7
# (590540,) | V13
# (590540,) | V315
# (590540,) | V18
# (590540,) | V211
# (590540,) | V138
# (590540,) | V264
# (590540,) | V114
# (590540,) | V304
# (590540,) | V272
# (590540,) | D13
# (590540,) | V330
# (590540,) | V267
# (590540,) | V303
# (590540,) | V286
# (590540,) | V46
# (590540,) | V96
# (590540,) | V91
# (590540,) | V124
# (590540,) | D8
# (590540,) | V305
# (590540,) | V2
# (590540,) | R_emaildomain_aim.com_dummie
# (590540,) | R_emaildomain_anonymous.com_dummie
# (590540,) | R_emaildomain_aol.com_dummie
# (590540,) | R_emaildomain_att.net_dummie
# (590540,) | R_emaildomain_bellsouth.net_dummie
# (590540,) | R_emaildomain_cableone.net_dummie
# (590540,) | R_emaildomain_centurylink.net_dummie
# (590540,) | R_emaildomain_cfl.rr.com_dummie
# (590540,) | R_emaildomain_charter.net_dummie
# (590540,) | R_emaildomain_comcast.net_dummie
# (590540,) | R_emaildomain_cox.net_dummie
# (590540,) | R_emaildomain_earthlink.net_dummie
# (590540,) | R_emaildomain_embarqmail.com_dummie
# (590540,) | R_emaildomain_frontier.com_dummie
# (590540,) | R_emaildomain_frontiernet.net_dummie
# (590540,) | R_emaildomain_gmail_dummie
# (590540,) | R_emaildomain_gmail.com_dummie
# (590540,) | R_emaildomain_gmx.de_dummie
# (590540,) | R_emaildomain_hotmail.co.uk_dummie
# (590540,) | R_emaildomain_hotmail.com_dummie
# (590540,) | R_emaildomain_hotmail.de_dummie
# (590540,) | R_emaildomain_hotmail.es_dummie
# (590540,) | R_emaildomain_hotmail.fr_dummie
# (590540,) | R_emaildomain_icloud.com_dummie
# (590540,) | R_emaildomain_juno.com_dummie
# (590540,) | R_emaildomain_live.com_dummie
# (590540,) | R_emaildomain_live.com.mx_dummie
# (590540,) | R_emaildomain_live.fr_dummie
# (590540,) | R_emaildomain_mac.com_dummie
# (590540,) | R_emaildomain_mail.com_dummie
# (590540,) | R_emaildomain_me.com_dummie
# (590540,) | R_emaildomain_msn.com_dummie
# (590540,) | R_emaildomain_netzero.com_dummie
# (590540,) | R_emaildomain_netzero.net_dummie
# (590540,) | R_emaildomain_optonline.net_dummie
# (590540,) | R_emaildomain_outlook.com_dummie
# (590540,) | R_emaildomain_outlook.es_dummie
# (590540,) | R_emaildomain_prodigy.net.mx_dummie
# (590540,) | R_emaildomain_protonmail.com_dummie
# (590540,) | R_emaildomain_ptd.net_dummie
# (590540,) | R_emaildomain_q.com_dummie
# (590540,) | R_emaildomain_roadrunner.com_dummie
# (590540,) | R_emaildomain_rocketmail.com_dummie
# (590540,) | R_emaildomain_sbcglobal.net_dummie
# (590540,) | R_emaildomain_sc.rr.com_dummie
# (590540,) | R_emaildomain_scranton.edu_dummie
# (590540,) | R_emaildomain_servicios-ta.com_dummie
# (590540,) | R_emaildomain_suddenlink.net_dummie
# (590540,) | R_emaildomain_twc.com_dummie
# (590540,) | R_emaildomain_verizon.net_dummie
# (590540,) | R_emaildomain_web.de_dummie
# (590540,) | R_emaildomain_windstream.net_dummie
# (590540,) | R_emaildomain_yahoo.co.jp_dummie
# (590540,) | R_emaildomain_yahoo.co.uk_dummie
# (590540,) | R_emaildomain_yahoo.com_dummie
# (590540,) | R_emaildomain_yahoo.com.mx_dummie
# (590540,) | R_emaildomain_yahoo.de_dummie
# (590540,) | R_emaildomain_yahoo.es_dummie
# (590540,) | R_emaildomain_yahoo.fr_dummie
# (590540,) | R_emaildomain_ymail.com_dummie
# (590540,) | M7_F_dummie
# (590540,) | M7_T_dummie
# (590540,) | M3_F_dummie
# (590540,) | M3_T_dummie
# (590540,) | P_emaildomain_aim.com_dummie
# (590540,) | P_emaildomain_anonymous.com_dummie
# (590540,) | P_emaildomain_aol.com_dummie
# (590540,) | P_emaildomain_att.net_dummie
# (590540,) | P_emaildomain_bellsouth.net_dummie
# (590540,) | P_emaildomain_cableone.net_dummie
# (590540,) | P_emaildomain_centurylink.net_dummie
# (590540,) | P_emaildomain_cfl.rr.com_dummie
# (590540,) | P_emaildomain_charter.net_dummie
# (590540,) | P_emaildomain_comcast.net_dummie
# (590540,) | P_emaildomain_cox.net_dummie
# (590540,) | P_emaildomain_earthlink.net_dummie
# (590540,) | P_emaildomain_embarqmail.com_dummie
# (590540,) | P_emaildomain_frontier.com_dummie
# (590540,) | P_emaildomain_frontiernet.net_dummie
# (590540,) | P_emaildomain_gmail_dummie
# (590540,) | P_emaildomain_gmail.com_dummie
# (590540,) | P_emaildomain_gmx.de_dummie
# (590540,) | P_emaildomain_hotmail.co.uk_dummie
# (590540,) | P_emaildomain_hotmail.com_dummie
# (590540,) | P_emaildomain_hotmail.de_dummie
# (590540,) | P_emaildomain_hotmail.es_dummie
# (590540,) | P_emaildomain_hotmail.fr_dummie
# (590540,) | P_emaildomain_icloud.com_dummie
# (590540,) | P_emaildomain_juno.com_dummie
# (590540,) | P_emaildomain_live.com_dummie
# (590540,) | P_emaildomain_live.com.mx_dummie
# (590540,) | P_emaildomain_live.fr_dummie
# (590540,) | P_emaildomain_mac.com_dummie
# (590540,) | P_emaildomain_mail.com_dummie
# (590540,) | P_emaildomain_me.com_dummie
# (590540,) | P_emaildomain_msn.com_dummie
# (590540,) | P_emaildomain_netzero.com_dummie
# (590540,) | P_emaildomain_netzero.net_dummie
# (590540,) | P_emaildomain_optonline.net_dummie
# (590540,) | P_emaildomain_outlook.com_dummie
# (590540,) | P_emaildomain_outlook.es_dummie
# (590540,) | P_emaildomain_prodigy.net.mx_dummie
# (590540,) | P_emaildomain_protonmail.com_dummie
# (590540,) | P_emaildomain_ptd.net_dummie
# (590540,) | P_emaildomain_q.com_dummie
# (590540,) | P_emaildomain_roadrunner.com_dummie
# (590540,) | P_emaildomain_rocketmail.com_dummie
# (590540,) | P_emaildomain_sbcglobal.net_dummie
# (590540,) | P_emaildomain_sc.rr.com_dummie
# (590540,) | P_emaildomain_servicios-ta.com_dummie
# (590540,) | P_emaildomain_suddenlink.net_dummie
# (590540,) | P_emaildomain_twc.com_dummie
# (590540,) | P_emaildomain_verizon.net_dummie
# (590540,) | P_emaildomain_web.de_dummie
# (590540,) | P_emaildomain_windstream.net_dummie
# (590540,) | P_emaildomain_yahoo.co.jp_dummie
# (590540,) | P_emaildomain_yahoo.co.uk_dummie
# (590540,) | P_emaildomain_yahoo.com_dummie
# (590540,) | P_emaildomain_yahoo.com.mx_dummie
# (590540,) | P_emaildomain_yahoo.de_dummie
# (590540,) | P_emaildomain_yahoo.es_dummie
# (590540,) | P_emaildomain_yahoo.fr_dummie
# (590540,) | P_emaildomain_ymail.com_dummie
# (590540,) | card4_american express_dummie
# (590540,) | card4_discover_dummie
# (590540,) | card4_mastercard_dummie
# (590540,) | card4_visa_dummie
# (590540,) | M9_F_dummie
# (590540,) | M9_T_dummie
# (590540,) | card6_charge card_dummie
# (590540,) | card6_credit_dummie
# (590540,) | card6_debit_dummie
# (590540,) | card6_debit or credit_dummie
# (590540,) | M5_F_dummie
# (590540,) | M5_T_dummie
# (590540,) | M6_F_dummie
# (590540,) | M6_T_dummie
# (590540,) | M2_F_dummie
# (590540,) | M2_T_dummie
# (590540,) | M1_F_dummie
# (590540,) | M1_T_dummie
# (590540,) | M4_M0_dummie
# (590540,) | M4_M1_dummie
# (590540,) | M4_M2_dummie
# (590540,) | M8_F_dummie
# (590540,) | M8_T_dummie
# (590540,) | ProductCD_C_dummie
# (590540,) | ProductCD_H_dummie
# (590540,) | ProductCD_R_dummie
# (590540,) | ProductCD_S_dummie
# (590540,) | ProductCD_W_dummie

# %%
# User Group
# pred_user = pd.read_csv('../output/0830_ieee__same_user__pattern-user_keys__card_addr.csv')
pred_user = pd.read_csv('../output/same_user_pattern/20190901_user_ids_share.csv')
pred_user['same_user_id'] = pred_user['predicted_user_id']
pred_user.loc[pred_user[pred_user['predicted_user_id'].isnull()].index, 'same_user_id'] = pred_user.loc[pred_user[pred_user['predicted_user_id'].isnull()].index, COLUMN_ID]
pred_user['same_user_id'] = pred_user['same_user_id'].astype('int')
pred_user.set_index(COLUMN_ID, inplace=True)

df_train.set_index(COLUMN_ID, inplace=True)
df_test.set_index(COLUMN_ID, inplace=True)
df_train['pred_user'] = pred_user['same_user_id']
df_test['pred_user'] = pred_user['same_user_id']
df_train.reset_index(inplace=True)
df_test.reset_index(inplace=True)

# %%
Y = df_train[COLUMN_TARGET]
df_train.drop(COLUMN_TARGET, axis=1, inplace=True)
kfold = list(GroupKFold(n_splits=5).split(df_train, Y, df_train["pred_user"]))

# %%
# Train or Testにしかないfeatureが存在しないようにする
cols_train = [col for col in df_train.columns if col not in COLUMNS_IGNORE]
cols_test = [col for col in df_test.columns if col not in COLUMNS_IGNORE]
use_cols = list(set(cols_train) & set(cols_test))

# %%
# 情報をもたない or 重複してるようなfeatureを除く
list_unique_drop = drop_unique_feature(df_train, df_test, use_cols, drop=False)
list_corr_drop = drop_high_corr_feature(df_train, df_test, use_cols, drop=False)
move_feature(list(set(list_corr_drop)), 'raw_use', 'raw_trush', prefix='raw__')
# Out:
#  41%|████      | 216/525 [00:00<00:00, 1067.69it/s]
# highly correlated: V329 / V105
# highly correlated: V97 / V324
# highly correlated: C7 / C12
#  60%|██████    | 317/525 [00:00<00:00, 607.55it/s]
# highly correlated: V95 / V322
# highly correlated: R_emaildomain_servicios-ta.com_dummie / P_emaildomain_servicios-ta.com_dummie
# highly correlated: V324 / V280
# highly correlated: P_emaildomain_prodigy.net.mx_dummie / R_emaildomain_prodigy.net.mx_dummie
#  85%|████████▌ | 448/525 [00:00<00:00, 363.04it/s]
# highly correlated: D12 / D4
# highly correlated: V323 / V96
# highly correlated: V167 / V177
# highly correlated: V322 / V279
# highly correlated: V324 / V103
# highly correlated: V95 / V101
# highly correlated: V322 / V101
# 100%|██████████| 525/525 [00:01<00:00, 444.55it/s]
# highly correlated: V322 / V293
# highly correlated: V279 / V293

# %%
model_type = 'lgb'
params = {
    'n_jobs': 40,
    'seed': 1208,
    'n_splits': 5,
    'metric': 'auc',
    'model_type': model_type,
    'objective': 'binary',
    'fold': ['stratified', 'group'][1],
    
    'num_leaves': 2**6-1,
    'max_depth': -1,
    'subsample': 1.0,
    'subsample_freq': 1,
    'colsample_bytree' : 0.25,
    'lambda_l1' : 0.1,
    'lambda_l2' : 1.0,
    'learning_rate' : 0.1,
}

best_iteration, cv_score, df_feim, pred_result, score_list = ieee_cv(df_train, Y, df_test, use_cols, params)

test_pred = pred_result.values[len(df_train):]
valid_submit_prediction(test_pred)
# Out:
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's auc: 0.901542
# Early stopping, best iteration is:
# [212]	valid_0's auc: 0.901653
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [109]	valid_0's auc: 0.890612
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [51]	valid_0's auc: 0.88186
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [95]	valid_0's auc: 0.896769
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [140]	valid_0's auc: 0.891794

# %%
# Importanceの低いFeatureは除外する
useless_features = feim_df[feim_df['imp_avg']<=200].index.tolist()
move_feature(useless_features, 'raw_use', 'raw_trush', prefix='raw__')

# %%
#========================================================================
# Adversarial Validation
#========================================================================
df_train['is_train'] = 1
df_test['is_train']  = 0
all_data = pd.concat([df_train, df_test], axis=0)
COLUMN_ADV = 'is_train'

Y_ADV = all_data[COLUMN_ADV]
all_data.drop(COLUMN_ADV, axis=1, inplace=True)
kfold = list(GroupKFold(n_splits=5).split(all_data, Y_ADV, all_data["pred_user"]))

model_type = 'lgb'
params = {
    'n_jobs': 40,
    'seed': 1208,
    'n_splits': 5,
    'metric': 'auc',
    'model_type': model_type,
    'objective': 'binary',
    'fold': ['stratified', 'group'][1],
    
    'num_leaves': 2**6-1,
    'max_depth': -1,
    'subsample': 1.0,
    'subsample_freq': 1,
    'colsample_bytree' : 0.25,
    'lambda_l1' : 0.1,
    'lambda_l2' : 1.0,
    'learning_rate' : 0.1,
}

adv_cv_score, adv_feim_df, adv_pred_result = ieee_cv(
    all_data,
    Y_ADV,
    [],
    use_cols,
    params,
    is_adv=True
)
# Out:
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's auc: 0.935023
# [400]	valid_0's auc: 0.940121
# [600]	valid_0's auc: 0.943592
# [800]	valid_0's auc: 0.945213
# [1000]	valid_0's auc: 0.946541
# [1200]	valid_0's auc: 0.947765
# [1400]	valid_0's auc: 0.948202
# Early stopping, best iteration is:
# [1392]	valid_0's auc: 0.948307
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's auc: 0.935876
# [400]	valid_0's auc: 0.942171
# [600]	valid_0's auc: 0.944441
# [800]	valid_0's auc: 0.946336
# [1000]	valid_0's auc: 0.947303
# [1200]	valid_0's auc: 0.948015
# [1400]	valid_0's auc: 0.948615
# [1600]	valid_0's auc: 0.949609
# Early stopping, best iteration is:
# [1748]	valid_0's auc: 0.949887
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's auc: 0.934275
# [400]	valid_0's auc: 0.940662
# [600]	valid_0's auc: 0.943786
# [800]	valid_0's auc: 0.945787
# [1000]	valid_0's auc: 0.947027
# [1200]	valid_0's auc: 0.947871
# [1400]	valid_0's auc: 0.94856
# [1600]	valid_0's auc: 0.949151
# [1800]	valid_0's auc: 0.94946
# [2000]	valid_0's auc: 0.950001
# [2200]	valid_0's auc: 0.950284
# [2400]	valid_0's auc: 0.950783
# Early stopping, best iteration is:
# [2380]	valid_0's auc: 0.950789
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's auc: 0.938216
# [400]	valid_0's auc: 0.944601
# [600]	valid_0's auc: 0.947283
# [800]	valid_0's auc: 0.948696
# [1000]	valid_0's auc: 0.949705
# [1200]	valid_0's auc: 0.950674
# Early stopping, best iteration is:
# [1226]	valid_0's auc: 0.950747
# Training until validation scores don't improve for 50 rounds.
# [200]	valid_0's auc: 0.937207
# [400]	valid_0's auc: 0.94302
# [600]	valid_0's auc: 0.946106
# [800]	valid_0's auc: 0.947389
# [1000]	valid_0's auc: 0.948519
# [1200]	valid_0's auc: 0.94933
# [1400]	valid_0's auc: 0.950038
# [1600]	valid_0's auc: 0.950395
# [1800]	valid_0's auc: 0.950836
# [2000]	valid_0's auc: 0.951031
# [2200]	valid_0's auc: 0.951462
# Early stopping, best iteration is:
# [2251]	valid_0's auc: 0.951585

# %%
#========================================================================
# 学習結果やパラメータのログをBigQueryに保存する
#========================================================================
n_features = len(use_cols)
n_rows = df_train.shape[0]
save_log_cv_result(
    best_iteration,
    cv_score,
    feim_df,
    model_type,
    n_features,
    n_rows,
    params,
    pred_result,
    score_list,
    adv_cv_score
)
# Out:
# Setup Dataset dim_ml_dataset.
