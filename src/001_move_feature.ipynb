# %%
from kaggle_utils import move_feature
from glob import glob

train_paths = glob('../feature/raw_main/*_train.gz')

# %%
# 不要なV系featureの移動
no_list = [19,20
,23,24
,55,56
,61,62,66,67
,77,78
,86,87
,95,97,99
,101,103,126,127,128,130,132,133,134
,279,280,282,283,285,291,292,293,294,295
,303,304,306,307,308,310,316,317,318]
list_feature = []
for no in no_list:
    col_V = f"V{no}"
    list_feature.append(col_V)
move_feature(list_feature, 'raw_use', 'raw_trush')
