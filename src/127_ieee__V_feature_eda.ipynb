# %%
from func.utils import get_categorical_features, read_pkl_gzip, to_pkl_gzip, parallel_load_data, get_filename
import pandas as pd
pd.set_option('max_rows', 200)
pd.Series(read_pkl_gzip('../feature/create/524__TransactionAmt_fraud_mean_train.gz')).value_counts().sort_index(ascending=False)
# Out:
# 1.000000      398
# 0.965517        2
# 0.950000        1
# 0.933333        1
# 0.931035        4
# 0.928571       12
# 0.909091        1
# 0.897959        2
# 0.884615        5
# 0.875000       11
# 0.870968        6
# 0.866667        8
# 0.857143       32
# 0.846154        2
# 0.833333       48
# 0.825000        5
# 0.823529       15
# 0.818182       24
# 0.814815        3
# 0.809524        6
# 0.807692        2
# 0.800000       25
# 0.795181        1
# 0.794872        4
# 0.789474       21
# 0.785714       22
# 0.782609       12
# 0.777778       21
# 0.772727        3
# 0.769231        1
# 0.750000      114
# 0.736842       17
# 0.730769       55
# 0.727273        2
# 0.714286       43
# 0.705882        1
# 0.700000       19
# 0.692308        2
# 0.687500        7
# 0.684211        4
# 0.680000        8
# 0.677419       13
# 0.673913       10
# 0.666667      201
# 0.657143       22
# 0.653846       15
# 0.647059       22
# 0.636364       27
# 0.631579       25
# 0.625000       55
# ...
